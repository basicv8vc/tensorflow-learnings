# %% [markdown]
# # Reading Data

# %% [markdown]
# TensorFlow程序获取数据的方法主要有三种：
# * Feeding：Python代码提供数据
# * Reading from files: 从文件读取数据
# * Preloaded data: TensorFlow计算图中用constant或variable保存数据（只能是小数据集）

# %% [markdown]
# ## Feeding

# %% [markdown]
# TensorFlow的Feeding机制允许你为计算图中任意Tensor注入数据。Python中可以直接为图节点提供数据。
#
# 为run()或eval()的`feed_dict`参数提供数据。

# %%
with tf.Session():
    input = tf.placeholder(tf.float32)
    classifier = ...
    print(classifier.eval(feed_dict={input: my_python_preprocessing_fn()}))

# %% [markdown]
# 你可以为任何Tensor进行feed数据，也包括constant和variable，我们建议还是为那些`tf.placholder`节点进行feed data。可以这么说，**placeholder存在的意义就是作为feed的目标**。如果你忘了给placeholder feed data，就执行程序，是会报错滴。

# %% [markdown]
# ## Reading from files

# %% [markdown]
# 如果要从文件读取数据，pipeline通常包括下面的步骤:
#
# * 1. 文件名列表
# * 2. （可选的）文件名shuffle
# * 3. (可选的) epoch limit
# * 4. 文件名队列
# * 5. Reader
# * 6. 解码器，解码reader读取的record
# * 7. （可选的）预处理
# * 8. 实力队列

# %% [markdown]
# ### 文件名、shuffling、epoch limit

# %% [markdown]
# 对于文件名列表，可以用一个string Tensor表示,["file0", "file1"]或[("fiel%d" %i) for i in range(2)]；也可以用`tf.train.match_filenames_once`方法。
#
#
#
# 把文件名列表传给`tf.train.string_input_producer`方法。它会创建一个队列来保存文件名。

# %% [markdown]
# #### 文件格式

# %% [markdown]
# **CSV文件**

# %% [markdown]
# 使用`tf.TextLineReader`和`tf.decode_csv`读取csv文件：

# %%
import tensorflow as tf
filename_queue = tf.train.string_input_producer(["file0.csv", "file1.csv"], num_epochs=1, shuffle=False)

reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# 默认值
record_defaults = [[1], [1], [1], [1], [1]]
col1, col2, col3, col4, col5 = tf.decode_csv(
        value, record_defaults=record_defaults)
features = tf.stack([col1, col2, col3, col4])

with tf.Session() as session:
    # Start populating the filename queue
    session.run(tf.global_variables_initializer())
    session.run(tf.local_variables_initializer())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    ct = 1
    
    while True:
        try:
            example, label = session.run([features, col5])
            print(example, label, ct)
            ct += 1
        except tf.errors.OutOfRangeError:
            break
        
    coord.request_stop()
    coord.join(threads)
# Out:
# (array([2, 1, 2, 1], dtype=int32), 6, 1)
# (array([1, 1, 1, 1], dtype=int32), 5, 2)
# (array([2, 2, 2, 2], dtype=int32), 6, 3)
# (array([1, 1, 1, 1], dtype=int32), 4, 4)
# (array([2, 2, 2, 2], dtype=int32), 5, 5)
# (array([1, 2, 1, 2], dtype=int32), 5, 6)
# (array([1, 1, 1, 1], dtype=int32), 4, 7)
# (array([2, 2, 2, 2], dtype=int32), 5, 8)
# (array([1, 2, 1, 2], dtype=int32), 5, 9)
# (array([2, 1, 2, 1], dtype=int32), 6, 10)
# (array([1, 1, 1, 1], dtype=int32), 5, 11)
# (array([2, 2, 2, 2], dtype=int32), 6, 12)
# (array([2, 1, 2, 1], dtype=int32), 6, 13)
# (array([1, 1, 1, 1], dtype=int32), 5, 14)
# (array([2, 2, 2, 2], dtype=int32), 6, 15)
# (array([1, 1, 1, 1], dtype=int32), 4, 16)
# (array([2, 2, 2, 2], dtype=int32), 5, 17)
# (array([1, 2, 1, 2], dtype=int32), 5, 18)
# (array([2, 1, 2, 1], dtype=int32), 6, 19)
# (array([1, 1, 1, 1], dtype=int32), 5, 20)
# (array([2, 2, 2, 2], dtype=int32), 6, 21)
# (array([1, 1, 1, 1], dtype=int32), 4, 22)
# (array([2, 2, 2, 2], dtype=int32), 5, 23)
# (array([1, 2, 1, 2], dtype=int32), 5, 24)
# (array([2, 1, 2, 1], dtype=int32), 6, 25)
# (array([1, 1, 1, 1], dtype=int32), 5, 26)
# (array([2, 2, 2, 2], dtype=int32), 6, 27)
# (array([1, 1, 1, 1], dtype=int32), 4, 28)
# (array([2, 2, 2, 2], dtype=int32), 5, 29)
# (array([1, 2, 1, 2], dtype=int32), 5, 30)
# (array([2, 1, 2, 1], dtype=int32), 6, 31)
# (array([1, 1, 1, 1], dtype=int32), 5, 32)
# (array([2, 2, 2, 2], dtype=int32), 6, 33)
# (array([1, 1, 1, 1], dtype=int32), 4, 34)
# (array([2, 2, 2, 2], dtype=int32), 5, 35)
# (array([1, 2, 1, 2], dtype=int32), 5, 36)
# (array([2, 1, 2, 1], dtype=int32), 6, 37)
# (array([1, 1, 1, 1], dtype=int32), 5, 38)
# (array([2, 2, 2, 2], dtype=int32), 6, 39)
# (array([1, 1, 1, 1], dtype=int32), 4, 40)
# (array([2, 2, 2, 2], dtype=int32), 5, 41)
# (array([1, 2, 1, 2], dtype=int32), 5, 42)
# (array([1, 1, 1, 1], dtype=int32), 4, 43)
# (array([2, 2, 2, 2], dtype=int32), 5, 44)
# (array([1, 2, 1, 2], dtype=int32), 5, 45)
# (array([2, 1, 2, 1], dtype=int32), 6, 46)
# (array([1, 1, 1, 1], dtype=int32), 5, 47)
# (array([2, 2, 2, 2], dtype=int32), 6, 48)
# (array([2, 1, 2, 1], dtype=int32), 6, 49)
# (array([1, 1, 1, 1], dtype=int32), 5, 50)
# (array([2, 2, 2, 2], dtype=int32), 6, 51)
# (array([1, 1, 1, 1], dtype=int32), 4, 52)
# (array([2, 2, 2, 2], dtype=int32), 5, 53)
# (array([1, 2, 1, 2], dtype=int32), 5, 54)
# (array([1, 1, 1, 1], dtype=int32), 4, 55)
# (array([2, 2, 2, 2], dtype=int32), 5, 56)
# (array([1, 2, 1, 2], dtype=int32), 5, 57)
# (array([2, 1, 2, 1], dtype=int32), 6, 58)
# (array([1, 1, 1, 1], dtype=int32), 5, 59)
# (array([2, 2, 2, 2], dtype=int32), 6, 60)
# (array([2, 1, 2, 1], dtype=int32), 6, 61)
# (array([1, 1, 1, 1], dtype=int32), 5, 62)
# (array([2, 2, 2, 2], dtype=int32), 6, 63)
# (array([1, 1, 1, 1], dtype=int32), 4, 64)
# (array([2, 2, 2, 2], dtype=int32), 5, 65)
# (array([1, 2, 1, 2], dtype=int32), 5, 66)
# (array([2, 1, 2, 1], dtype=int32), 6, 67)
# (array([1, 1, 1, 1], dtype=int32), 5, 68)
# (array([2, 2, 2, 2], dtype=int32), 6, 69)
# (array([1, 1, 1, 1], dtype=int32), 4, 70)
# (array([2, 2, 2, 2], dtype=int32), 5, 71)
# (array([1, 2, 1, 2], dtype=int32), 5, 72)
# (array([1, 1, 1, 1], dtype=int32), 4, 73)
# (array([2, 2, 2, 2], dtype=int32), 5, 74)
# (array([1, 2, 1, 2], dtype=int32), 5, 75)
# (array([2, 1, 2, 1], dtype=int32), 6, 76)
# (array([1, 1, 1, 1], dtype=int32), 5, 77)
# (array([2, 2, 2, 2], dtype=int32), 6, 78)
# (array([2, 1, 2, 1], dtype=int32), 6, 79)
# (array([1, 1, 1, 1], dtype=int32), 5, 80)
# (array([2, 2, 2, 2], dtype=int32), 6, 81)
# (array([1, 1, 1, 1], dtype=int32), 4, 82)
# (array([2, 2, 2, 2], dtype=int32), 5, 83)
# (array([1, 2, 1, 2], dtype=int32), 5, 84)
# (array([1, 1, 1, 1], dtype=int32), 4, 85)
# (array([2, 2, 2, 2], dtype=int32), 5, 86)
# (array([1, 2, 1, 2], dtype=int32), 5, 87)
# (array([2, 1, 2, 1], dtype=int32), 6, 88)
# (array([1, 1, 1, 1], dtype=int32), 5, 89)
# (array([2, 2, 2, 2], dtype=int32), 6, 90)
# (array([1, 1, 1, 1], dtype=int32), 4, 91)
# (array([2, 2, 2, 2], dtype=int32), 5, 92)
# (array([1, 2, 1, 2], dtype=int32), 5, 93)
# (array([2, 1, 2, 1], dtype=int32), 6, 94)
# (array([1, 1, 1, 1], dtype=int32), 5, 95)
# (array([2, 2, 2, 2], dtype=int32), 6, 96)
# (array([1, 1, 1, 1], dtype=int32), 4, 97)
# (array([2, 2, 2, 2], dtype=int32), 5, 98)
# (array([1, 2, 1, 2], dtype=int32), 5, 99)
# (array([2, 1, 2, 1], dtype=int32), 6, 100)
# (array([1, 1, 1, 1], dtype=int32), 5, 101)
# (array([2, 2, 2, 2], dtype=int32), 6, 102)
# (array([2, 1, 2, 1], dtype=int32), 6, 103)
# (array([1, 1, 1, 1], dtype=int32), 5, 104)
# (array([2, 2, 2, 2], dtype=int32), 6, 105)
# (array([1, 1, 1, 1], dtype=int32), 4, 106)
# (array([2, 2, 2, 2], dtype=int32), 5, 107)
# (array([1, 2, 1, 2], dtype=int32), 5, 108)
# (array([1, 1, 1, 1], dtype=int32), 4, 109)
# (array([2, 2, 2, 2], dtype=int32), 5, 110)
# (array([1, 2, 1, 2], dtype=int32), 5, 111)
# (array([2, 1, 2, 1], dtype=int32), 6, 112)
# (array([1, 1, 1, 1], dtype=int32), 5, 113)
# (array([2, 2, 2, 2], dtype=int32), 6, 114)
# (array([1, 1, 1, 1], dtype=int32), 4, 115)
# (array([2, 2, 2, 2], dtype=int32), 5, 116)
# (array([1, 2, 1, 2], dtype=int32), 5, 117)
# (array([2, 1, 2, 1], dtype=int32), 6, 118)
# (array([1, 1, 1, 1], dtype=int32), 5, 119)
# (array([2, 2, 2, 2], dtype=int32), 6, 120)
# (array([1, 1, 1, 1], dtype=int32), 4, 121)
# (array([2, 2, 2, 2], dtype=int32), 5, 122)
# (array([1, 2, 1, 2], dtype=int32), 5, 123)
# (array([2, 1, 2, 1], dtype=int32), 6, 124)
# (array([1, 1, 1, 1], dtype=int32), 5, 125)
# (array([2, 2, 2, 2], dtype=int32), 6, 126)
# (array([2, 1, 2, 1], dtype=int32), 6, 127)
# (array([1, 1, 1, 1], dtype=int32), 5, 128)
# (array([2, 2, 2, 2], dtype=int32), 6, 129)
# (array([1, 1, 1, 1], dtype=int32), 4, 130)
# (array([2, 2, 2, 2], dtype=int32), 5, 131)
# (array([1, 2, 1, 2], dtype=int32), 5, 132)
# (array([2, 1, 2, 1], dtype=int32), 6, 133)
# (array([1, 1, 1, 1], dtype=int32), 5, 134)
# (array([2, 2, 2, 2], dtype=int32), 6, 135)
# (array([1, 1, 1, 1], dtype=int32), 4, 136)
# (array([2, 2, 2, 2], dtype=int32), 5, 137)
# (array([1, 2, 1, 2], dtype=int32), 5, 138)
# (array([2, 1, 2, 1], dtype=int32), 6, 139)
# (array([1, 1, 1, 1], dtype=int32), 5, 140)
# (array([2, 2, 2, 2], dtype=int32), 6, 141)
# (array([1, 1, 1, 1], dtype=int32), 4, 142)
# (array([2, 2, 2, 2], dtype=int32), 5, 143)
# (array([1, 2, 1, 2], dtype=int32), 5, 144)
# (array([1, 1, 1, 1], dtype=int32), 4, 145)
# (array([2, 2, 2, 2], dtype=int32), 5, 146)
# (array([1, 2, 1, 2], dtype=int32), 5, 147)
# (array([2, 1, 2, 1], dtype=int32), 6, 148)
# (array([1, 1, 1, 1], dtype=int32), 5, 149)
# (array([2, 2, 2, 2], dtype=int32), 6, 150)
# (array([1, 1, 1, 1], dtype=int32), 4, 151)
# (array([2, 2, 2, 2], dtype=int32), 5, 152)
# (array([1, 2, 1, 2], dtype=int32), 5, 153)
# (array([2, 1, 2, 1], dtype=int32), 6, 154)
# (array([1, 1, 1, 1], dtype=int32), 5, 155)
# (array([2, 2, 2, 2], dtype=int32), 6, 156)
# (array([1, 1, 1, 1], dtype=int32), 4, 157)
# (array([2, 2, 2, 2], dtype=int32), 5, 158)
# (array([1, 2, 1, 2], dtype=int32), 5, 159)
# (array([2, 1, 2, 1], dtype=int32), 6, 160)
# (array([1, 1, 1, 1], dtype=int32), 5, 161)
# (array([2, 2, 2, 2], dtype=int32), 6, 162)
# (array([2, 1, 2, 1], dtype=int32), 6, 163)
# (array([1, 1, 1, 1], dtype=int32), 5, 164)
# (array([2, 2, 2, 2], dtype=int32), 6, 165)
# (array([1, 1, 1, 1], dtype=int32), 4, 166)
# (array([2, 2, 2, 2], dtype=int32), 5, 167)
# (array([1, 2, 1, 2], dtype=int32), 5, 168)
# (array([2, 1, 2, 1], dtype=int32), 6, 169)
# (array([1, 1, 1, 1], dtype=int32), 5, 170)
# (array([2, 2, 2, 2], dtype=int32), 6, 171)
# (array([1, 1, 1, 1], dtype=int32), 4, 172)
# (array([2, 2, 2, 2], dtype=int32), 5, 173)
# (array([1, 2, 1, 2], dtype=int32), 5, 174)
# (array([2, 1, 2, 1], dtype=int32), 6, 175)
# (array([1, 1, 1, 1], dtype=int32), 5, 176)
# (array([2, 2, 2, 2], dtype=int32), 6, 177)
# (array([1, 1, 1, 1], dtype=int32), 4, 178)
# (array([2, 2, 2, 2], dtype=int32), 5, 179)
# (array([1, 2, 1, 2], dtype=int32), 5, 180)
# (array([1, 1, 1, 1], dtype=int32), 4, 181)
# (array([2, 2, 2, 2], dtype=int32), 5, 182)
# (array([1, 2, 1, 2], dtype=int32), 5, 183)
# (array([2, 1, 2, 1], dtype=int32), 6, 184)
# (array([1, 1, 1, 1], dtype=int32), 5, 185)
# (array([2, 2, 2, 2], dtype=int32), 6, 186)
# (array([2, 1, 2, 1], dtype=int32), 6, 187)
# (array([1, 1, 1, 1], dtype=int32), 5, 188)
# (array([2, 2, 2, 2], dtype=int32), 6, 189)
# (array([1, 1, 1, 1], dtype=int32), 4, 190)
# (array([2, 2, 2, 2], dtype=int32), 5, 191)
# (array([1, 2, 1, 2], dtype=int32), 5, 192)
# (array([2, 1, 2, 1], dtype=int32), 6, 193)
# (array([1, 1, 1, 1], dtype=int32), 5, 194)
# (array([2, 2, 2, 2], dtype=int32), 6, 195)
# (array([1, 1, 1, 1], dtype=int32), 4, 196)
# (array([2, 2, 2, 2], dtype=int32), 5, 197)
# (array([1, 2, 1, 2], dtype=int32), 5, 198)
# (array([1, 1, 1, 1], dtype=int32), 4, 199)
# (array([2, 2, 2, 2], dtype=int32), 5, 200)
# (array([1, 2, 1, 2], dtype=int32), 5, 201)
# (array([2, 1, 2, 1], dtype=int32), 6, 202)
# (array([1, 1, 1, 1], dtype=int32), 5, 203)
# (array([2, 2, 2, 2], dtype=int32), 6, 204)
# (array([2, 1, 2, 1], dtype=int32), 6, 205)
# (array([1, 1, 1, 1], dtype=int32), 5, 206)
# (array([2, 2, 2, 2], dtype=int32), 6, 207)
# (array([1, 1, 1, 1], dtype=int32), 4, 208)
# (array([2, 2, 2, 2], dtype=int32), 5, 209)
# (array([1, 2, 1, 2], dtype=int32), 5, 210)
# (array([2, 1, 2, 1], dtype=int32), 6, 211)
# (array([1, 1, 1, 1], dtype=int32), 5, 212)
# (array([2, 2, 2, 2], dtype=int32), 6, 213)
# (array([1, 1, 1, 1], dtype=int32), 4, 214)
# (array([2, 2, 2, 2], dtype=int32), 5, 215)
# (array([1, 2, 1, 2], dtype=int32), 5, 216)
# (array([2, 1, 2, 1], dtype=int32), 6, 217)
# (array([1, 1, 1, 1], dtype=int32), 5, 218)
# (array([2, 2, 2, 2], dtype=int32), 6, 219)
# (array([1, 1, 1, 1], dtype=int32), 4, 220)
# (array([2, 2, 2, 2], dtype=int32), 5, 221)
# (array([1, 2, 1, 2], dtype=int32), 5, 222)
# (array([2, 1, 2, 1], dtype=int32), 6, 223)
# (array([1, 1, 1, 1], dtype=int32), 5, 224)
# (array([2, 2, 2, 2], dtype=int32), 6, 225)
# (array([1, 1, 1, 1], dtype=int32), 4, 226)
# (array([2, 2, 2, 2], dtype=int32), 5, 227)
# (array([1, 2, 1, 2], dtype=int32), 5, 228)
# (array([2, 1, 2, 1], dtype=int32), 6, 229)
# (array([1, 1, 1, 1], dtype=int32), 5, 230)
# (array([2, 2, 2, 2], dtype=int32), 6, 231)
# (array([1, 1, 1, 1], dtype=int32), 4, 232)
# (array([2, 2, 2, 2], dtype=int32), 5, 233)
# (array([1, 2, 1, 2], dtype=int32), 5, 234)
# (array([2, 1, 2, 1], dtype=int32), 6, 235)
# (array([1, 1, 1, 1], dtype=int32), 5, 236)
# (array([2, 2, 2, 2], dtype=int32), 6, 237)
# (array([1, 1, 1, 1], dtype=int32), 4, 238)
# (array([2, 2, 2, 2], dtype=int32), 5, 239)
# (array([1, 2, 1, 2], dtype=int32), 5, 240)
# (array([2, 1, 2, 1], dtype=int32), 6, 241)
# (array([1, 1, 1, 1], dtype=int32), 5, 242)
# (array([2, 2, 2, 2], dtype=int32), 6, 243)
# (array([1, 1, 1, 1], dtype=int32), 4, 244)
# (array([2, 2, 2, 2], dtype=int32), 5, 245)
# (array([1, 2, 1, 2], dtype=int32), 5, 246)
# (array([2, 1, 2, 1], dtype=int32), 6, 247)
# (array([1, 1, 1, 1], dtype=int32), 5, 248)
# (array([2, 2, 2, 2], dtype=int32), 6, 249)
# (array([1, 1, 1, 1], dtype=int32), 4, 250)
# (array([2, 2, 2, 2], dtype=int32), 5, 251)
# (array([1, 2, 1, 2], dtype=int32), 5, 252)
# (array([1, 1, 1, 1], dtype=int32), 4, 253)
# (array([2, 2, 2, 2], dtype=int32), 5, 254)
# (array([1, 2, 1, 2], dtype=int32), 5, 255)
# (array([2, 1, 2, 1], dtype=int32), 6, 256)
# (array([1, 1, 1, 1], dtype=int32), 5, 257)
# (array([2, 2, 2, 2], dtype=int32), 6, 258)
# (array([1, 1, 1, 1], dtype=int32), 4, 259)
# (array([2, 2, 2, 2], dtype=int32), 5, 260)
# (array([1, 2, 1, 2], dtype=int32), 5, 261)
# (array([2, 1, 2, 1], dtype=int32), 6, 262)
# (array([1, 1, 1, 1], dtype=int32), 5, 263)
# (array([2, 2, 2, 2], dtype=int32), 6, 264)
# (array([2, 1, 2, 1], dtype=int32), 6, 265)
# (array([1, 1, 1, 1], dtype=int32), 5, 266)
# (array([2, 2, 2, 2], dtype=int32), 6, 267)
# (array([1, 1, 1, 1], dtype=int32), 4, 268)
# (array([2, 2, 2, 2], dtype=int32), 5, 269)
# (array([1, 2, 1, 2], dtype=int32), 5, 270)
# (array([1, 1, 1, 1], dtype=int32), 4, 271)
# (array([2, 2, 2, 2], dtype=int32), 5, 272)
# (array([1, 2, 1, 2], dtype=int32), 5, 273)
# (array([2, 1, 2, 1], dtype=int32), 6, 274)
# (array([1, 1, 1, 1], dtype=int32), 5, 275)
# (array([2, 2, 2, 2], dtype=int32), 6, 276)
# (array([1, 1, 1, 1], dtype=int32), 4, 277)
# (array([2, 2, 2, 2], dtype=int32), 5, 278)
# (array([1, 2, 1, 2], dtype=int32), 5, 279)
# (array([2, 1, 2, 1], dtype=int32), 6, 280)
# (array([1, 1, 1, 1], dtype=int32), 5, 281)
# (array([2, 2, 2, 2], dtype=int32), 6, 282)
# (array([2, 1, 2, 1], dtype=int32), 6, 283)
# (array([1, 1, 1, 1], dtype=int32), 5, 284)
# (array([2, 2, 2, 2], dtype=int32), 6, 285)
# (array([1, 1, 1, 1], dtype=int32), 4, 286)
# (array([2, 2, 2, 2], dtype=int32), 5, 287)
# (array([1, 2, 1, 2], dtype=int32), 5, 288)
# (array([2, 1, 2, 1], dtype=int32), 6, 289)
# (array([1, 1, 1, 1], dtype=int32), 5, 290)
# (array([2, 2, 2, 2], dtype=int32), 6, 291)
# (array([1, 1, 1, 1], dtype=int32), 4, 292)
# (array([2, 2, 2, 2], dtype=int32), 5, 293)
# (array([1, 2, 1, 2], dtype=int32), 5, 294)
# (array([1, 1, 1, 1], dtype=int32), 4, 295)
# (array([2, 2, 2, 2], dtype=int32), 5, 296)
# (array([1, 2, 1, 2], dtype=int32), 5, 297)
# (array([2, 1, 2, 1], dtype=int32), 6, 298)
# (array([1, 1, 1, 1], dtype=int32), 5, 299)
# (array([2, 2, 2, 2], dtype=int32), 6, 300)
# (array([1, 1, 1, 1], dtype=int32), 4, 301)
# (array([2, 2, 2, 2], dtype=int32), 5, 302)
# (array([1, 2, 1, 2], dtype=int32), 5, 303)
# (array([2, 1, 2, 1], dtype=int32), 6, 304)
# (array([1, 1, 1, 1], dtype=int32), 5, 305)
# (array([2, 2, 2, 2], dtype=int32), 6, 306)
# (array([2, 1, 2, 1], dtype=int32), 6, 307)
# (array([1, 1, 1, 1], dtype=int32), 5, 308)
# (array([2, 2, 2, 2], dtype=int32), 6, 309)
# (array([1, 1, 1, 1], dtype=int32), 4, 310)
# (array([2, 2, 2, 2], dtype=int32), 5, 311)
# (array([1, 2, 1, 2], dtype=int32), 5, 312)
# (array([1, 1, 1, 1], dtype=int32), 4, 313)
# (array([2, 2, 2, 2], dtype=int32), 5, 314)
# (array([1, 2, 1, 2], dtype=int32), 5, 315)
# (array([2, 1, 2, 1], dtype=int32), 6, 316)
# (array([1, 1, 1, 1], dtype=int32), 5, 317)
# (array([2, 2, 2, 2], dtype=int32), 6, 318)
# (array([2, 1, 2, 1], dtype=int32), 6, 319)
# (array([1, 1, 1, 1], dtype=int32), 5, 320)
# (array([2, 2, 2, 2], dtype=int32), 6, 321)
# (array([1, 1, 1, 1], dtype=int32), 4, 322)
# (array([2, 2, 2, 2], dtype=int32), 5, 323)
# (array([1, 2, 1, 2], dtype=int32), 5, 324)
# (array([1, 1, 1, 1], dtype=int32), 4, 325)
# (array([2, 2, 2, 2], dtype=int32), 5, 326)
# (array([1, 2, 1, 2], dtype=int32), 5, 327)
# (array([2, 1, 2, 1], dtype=int32), 6, 328)
# (array([1, 1, 1, 1], dtype=int32), 5, 329)
# (array([2, 2, 2, 2], dtype=int32), 6, 330)
# (array([1, 1, 1, 1], dtype=int32), 4, 331)
# (array([2, 2, 2, 2], dtype=int32), 5, 332)
# (array([1, 2, 1, 2], dtype=int32), 5, 333)
# (array([2, 1, 2, 1], dtype=int32), 6, 334)
# (array([1, 1, 1, 1], dtype=int32), 5, 335)
# (array([2, 2, 2, 2], dtype=int32), 6, 336)
# (array([2, 1, 2, 1], dtype=int32), 6, 337)
# (array([1, 1, 1, 1], dtype=int32), 5, 338)
# (array([2, 2, 2, 2], dtype=int32), 6, 339)
# (array([1, 1, 1, 1], dtype=int32), 4, 340)
# (array([2, 2, 2, 2], dtype=int32), 5, 341)
# (array([1, 2, 1, 2], dtype=int32), 5, 342)
# (array([2, 1, 2, 1], dtype=int32), 6, 343)
# (array([1, 1, 1, 1], dtype=int32), 5, 344)
# (array([2, 2, 2, 2], dtype=int32), 6, 345)
# (array([1, 1, 1, 1], dtype=int32), 4, 346)
# (array([2, 2, 2, 2], dtype=int32), 5, 347)
# (array([1, 2, 1, 2], dtype=int32), 5, 348)
# (array([1, 1, 1, 1], dtype=int32), 4, 349)
# (array([2, 2, 2, 2], dtype=int32), 5, 350)
# (array([1, 2, 1, 2], dtype=int32), 5, 351)
# (array([2, 1, 2, 1], dtype=int32), 6, 352)
# (array([1, 1, 1, 1], dtype=int32), 5, 353)
# (array([2, 2, 2, 2], dtype=int32), 6, 354)
# (array([2, 1, 2, 1], dtype=int32), 6, 355)
# (array([1, 1, 1, 1], dtype=int32), 5, 356)
# (array([2, 2, 2, 2], dtype=int32), 6, 357)
# (array([1, 1, 1, 1], dtype=int32), 4, 358)
# (array([2, 2, 2, 2], dtype=int32), 5, 359)
# (array([1, 2, 1, 2], dtype=int32), 5, 360)
# (array([2, 1, 2, 1], dtype=int32), 6, 361)
# (array([1, 1, 1, 1], dtype=int32), 5, 362)
# (array([2, 2, 2, 2], dtype=int32), 6, 363)
# (array([1, 1, 1, 1], dtype=int32), 4, 364)
# (array([2, 2, 2, 2], dtype=int32), 5, 365)
# (array([1, 2, 1, 2], dtype=int32), 5, 366)
# (array([1, 1, 1, 1], dtype=int32), 4, 367)
# (array([2, 2, 2, 2], dtype=int32), 5, 368)
# (array([1, 2, 1, 2], dtype=int32), 5, 369)
# (array([2, 1, 2, 1], dtype=int32), 6, 370)
# (array([1, 1, 1, 1], dtype=int32), 5, 371)
# (array([2, 2, 2, 2], dtype=int32), 6, 372)
# (array([2, 1, 2, 1], dtype=int32), 6, 373)
# (array([1, 1, 1, 1], dtype=int32), 5, 374)
# (array([2, 2, 2, 2], dtype=int32), 6, 375)
# (array([1, 1, 1, 1], dtype=int32), 4, 376)
# (array([2, 2, 2, 2], dtype=int32), 5, 377)
# (array([1, 2, 1, 2], dtype=int32), 5, 378)
# (array([2, 1, 2, 1], dtype=int32), 6, 379)
# (array([1, 1, 1, 1], dtype=int32), 5, 380)
# (array([2, 2, 2, 2], dtype=int32), 6, 381)
# (array([1, 1, 1, 1], dtype=int32), 4, 382)
# (array([2, 2, 2, 2], dtype=int32), 5, 383)
# (array([1, 2, 1, 2], dtype=int32), 5, 384)
# (array([1, 1, 1, 1], dtype=int32), 4, 385)
# (array([2, 2, 2, 2], dtype=int32), 5, 386)
# (array([1, 2, 1, 2], dtype=int32), 5, 387)
# (array([2, 1, 2, 1], dtype=int32), 6, 388)
# (array([1, 1, 1, 1], dtype=int32), 5, 389)
# (array([2, 2, 2, 2], dtype=int32), 6, 390)
# (array([1, 1, 1, 1], dtype=int32), 4, 391)
# (array([2, 2, 2, 2], dtype=int32), 5, 392)
# (array([1, 2, 1, 2], dtype=int32), 5, 393)
# (array([2, 1, 2, 1], dtype=int32), 6, 394)
# (array([1, 1, 1, 1], dtype=int32), 5, 395)
# (array([2, 2, 2, 2], dtype=int32), 6, 396)
# (array([2, 1, 2, 1], dtype=int32), 6, 397)
# (array([1, 1, 1, 1], dtype=int32), 5, 398)
# (array([2, 2, 2, 2], dtype=int32), 6, 399)
# (array([1, 1, 1, 1], dtype=int32), 4, 400)
# (array([2, 2, 2, 2], dtype=int32), 5, 401)
# (array([1, 2, 1, 2], dtype=int32), 5, 402)
# (array([2, 1, 2, 1], dtype=int32), 6, 403)
# (array([1, 1, 1, 1], dtype=int32), 5, 404)
# (array([2, 2, 2, 2], dtype=int32), 6, 405)
# (array([1, 1, 1, 1], dtype=int32), 4, 406)
# (array([2, 2, 2, 2], dtype=int32), 5, 407)
# (array([1, 2, 1, 2], dtype=int32), 5, 408)
# (array([1, 1, 1, 1], dtype=int32), 4, 409)
# (array([2, 2, 2, 2], dtype=int32), 5, 410)
# (array([1, 2, 1, 2], dtype=int32), 5, 411)
# (array([2, 1, 2, 1], dtype=int32), 6, 412)
# (array([1, 1, 1, 1], dtype=int32), 5, 413)
# (array([2, 2, 2, 2], dtype=int32), 6, 414)
# (array([2, 1, 2, 1], dtype=int32), 6, 415)
# (array([1, 1, 1, 1], dtype=int32), 5, 416)
# (array([2, 2, 2, 2], dtype=int32), 6, 417)
# (array([1, 1, 1, 1], dtype=int32), 4, 418)
# (array([2, 2, 2, 2], dtype=int32), 5, 419)
# (array([1, 2, 1, 2], dtype=int32), 5, 420)
# (array([2, 1, 2, 1], dtype=int32), 6, 421)
# (array([1, 1, 1, 1], dtype=int32), 5, 422)
# (array([2, 2, 2, 2], dtype=int32), 6, 423)
# (array([1, 1, 1, 1], dtype=int32), 4, 424)
# (array([2, 2, 2, 2], dtype=int32), 5, 425)
# (array([1, 2, 1, 2], dtype=int32), 5, 426)
# (array([2, 1, 2, 1], dtype=int32), 6, 427)
# (array([1, 1, 1, 1], dtype=int32), 5, 428)
# (array([2, 2, 2, 2], dtype=int32), 6, 429)
# (array([1, 1, 1, 1], dtype=int32), 4, 430)
# (array([2, 2, 2, 2], dtype=int32), 5, 431)
# (array([1, 2, 1, 2], dtype=int32), 5, 432)
# (array([1, 1, 1, 1], dtype=int32), 4, 433)
# (array([2, 2, 2, 2], dtype=int32), 5, 434)
# (array([1, 2, 1, 2], dtype=int32), 5, 435)
# (array([2, 1, 2, 1], dtype=int32), 6, 436)
# (array([1, 1, 1, 1], dtype=int32), 5, 437)
# (array([2, 2, 2, 2], dtype=int32), 6, 438)
# (array([2, 1, 2, 1], dtype=int32), 6, 439)
# (array([1, 1, 1, 1], dtype=int32), 5, 440)
# (array([2, 2, 2, 2], dtype=int32), 6, 441)
# (array([1, 1, 1, 1], dtype=int32), 4, 442)
# (array([2, 2, 2, 2], dtype=int32), 5, 443)
# (array([1, 2, 1, 2], dtype=int32), 5, 444)
# (array([1, 1, 1, 1], dtype=int32), 4, 445)
# (array([2, 2, 2, 2], dtype=int32), 5, 446)
# (array([1, 2, 1, 2], dtype=int32), 5, 447)
# (array([2, 1, 2, 1], dtype=int32), 6, 448)
# (array([1, 1, 1, 1], dtype=int32), 5, 449)
# (array([2, 2, 2, 2], dtype=int32), 6, 450)
# (array([1, 1, 1, 1], dtype=int32), 4, 451)
# (array([2, 2, 2, 2], dtype=int32), 5, 452)
# (array([1, 2, 1, 2], dtype=int32), 5, 453)
# (array([2, 1, 2, 1], dtype=int32), 6, 454)
# (array([1, 1, 1, 1], dtype=int32), 5, 455)
# (array([2, 2, 2, 2], dtype=int32), 6, 456)
# (array([1, 1, 1, 1], dtype=int32), 4, 457)
# (array([2, 2, 2, 2], dtype=int32), 5, 458)
# (array([1, 2, 1, 2], dtype=int32), 5, 459)
# (array([2, 1, 2, 1], dtype=int32), 6, 460)
# (array([1, 1, 1, 1], dtype=int32), 5, 461)
# (array([2, 2, 2, 2], dtype=int32), 6, 462)
# (array([1, 1, 1, 1], dtype=int32), 4, 463)
# (array([2, 2, 2, 2], dtype=int32), 5, 464)
# (array([1, 2, 1, 2], dtype=int32), 5, 465)
# (array([2, 1, 2, 1], dtype=int32), 6, 466)
# (array([1, 1, 1, 1], dtype=int32), 5, 467)
# (array([2, 2, 2, 2], dtype=int32), 6, 468)
# (array([1, 1, 1, 1], dtype=int32), 4, 469)
# (array([2, 2, 2, 2], dtype=int32), 5, 470)
# (array([1, 2, 1, 2], dtype=int32), 5, 471)
# (array([2, 1, 2, 1], dtype=int32), 6, 472)
# (array([1, 1, 1, 1], dtype=int32), 5, 473)
# (array([2, 2, 2, 2], dtype=int32), 6, 474)
# (array([2, 1, 2, 1], dtype=int32), 6, 475)
# (array([1, 1, 1, 1], dtype=int32), 5, 476)
# (array([2, 2, 2, 2], dtype=int32), 6, 477)
# (array([1, 1, 1, 1], dtype=int32), 4, 478)
# (array([2, 2, 2, 2], dtype=int32), 5, 479)
# (array([1, 2, 1, 2], dtype=int32), 5, 480)
# (array([2, 1, 2, 1], dtype=int32), 6, 481)
# (array([1, 1, 1, 1], dtype=int32), 5, 482)
# (array([2, 2, 2, 2], dtype=int32), 6, 483)
# (array([1, 1, 1, 1], dtype=int32), 4, 484)
# (array([2, 2, 2, 2], dtype=int32), 5, 485)
# (array([1, 2, 1, 2], dtype=int32), 5, 486)
# (array([2, 1, 2, 1], dtype=int32), 6, 487)
# (array([1, 1, 1, 1], dtype=int32), 5, 488)
# (array([2, 2, 2, 2], dtype=int32), 6, 489)
# (array([1, 1, 1, 1], dtype=int32), 4, 490)
# (array([2, 2, 2, 2], dtype=int32), 5, 491)
# (array([1, 2, 1, 2], dtype=int32), 5, 492)
# (array([1, 1, 1, 1], dtype=int32), 4, 493)
# (array([2, 2, 2, 2], dtype=int32), 5, 494)
# (array([1, 2, 1, 2], dtype=int32), 5, 495)
# (array([2, 1, 2, 1], dtype=int32), 6, 496)
# (array([1, 1, 1, 1], dtype=int32), 5, 497)
# (array([2, 2, 2, 2], dtype=int32), 6, 498)
# (array([2, 1, 2, 1], dtype=int32), 6, 499)
# (array([1, 1, 1, 1], dtype=int32), 5, 500)
# (array([2, 2, 2, 2], dtype=int32), 6, 501)
# (array([1, 1, 1, 1], dtype=int32), 4, 502)
# (array([2, 2, 2, 2], dtype=int32), 5, 503)
# (array([1, 2, 1, 2], dtype=int32), 5, 504)
# (array([1, 1, 1, 1], dtype=int32), 4, 505)
# (array([2, 2, 2, 2], dtype=int32), 5, 506)
# (array([1, 2, 1, 2], dtype=int32), 5, 507)
# (array([2, 1, 2, 1], dtype=int32), 6, 508)
# (array([1, 1, 1, 1], dtype=int32), 5, 509)
# (array([2, 2, 2, 2], dtype=int32), 6, 510)
# (array([1, 1, 1, 1], dtype=int32), 4, 511)
# (array([2, 2, 2, 2], dtype=int32), 5, 512)
# (array([1, 2, 1, 2], dtype=int32), 5, 513)
# (array([2, 1, 2, 1], dtype=int32), 6, 514)
# (array([1, 1, 1, 1], dtype=int32), 5, 515)
# (array([2, 2, 2, 2], dtype=int32), 6, 516)
# (array([2, 1, 2, 1], dtype=int32), 6, 517)
# (array([1, 1, 1, 1], dtype=int32), 5, 518)
# (array([2, 2, 2, 2], dtype=int32), 6, 519)
# (array([1, 1, 1, 1], dtype=int32), 4, 520)
# (array([2, 2, 2, 2], dtype=int32), 5, 521)
# (array([1, 2, 1, 2], dtype=int32), 5, 522)
# (array([2, 1, 2, 1], dtype=int32), 6, 523)
# (array([1, 1, 1, 1], dtype=int32), 5, 524)
# (array([2, 2, 2, 2], dtype=int32), 6, 525)
# (array([1, 1, 1, 1], dtype=int32), 4, 526)
# (array([2, 2, 2, 2], dtype=int32), 5, 527)
# (array([1, 2, 1, 2], dtype=int32), 5, 528)
# (array([2, 1, 2, 1], dtype=int32), 6, 529)
# (array([1, 1, 1, 1], dtype=int32), 5, 530)
# (array([2, 2, 2, 2], dtype=int32), 6, 531)
# (array([1, 1, 1, 1], dtype=int32), 4, 532)
# (array([2, 2, 2, 2], dtype=int32), 5, 533)
# (array([1, 2, 1, 2], dtype=int32), 5, 534)
# (array([1, 1, 1, 1], dtype=int32), 4, 535)
# (array([2, 2, 2, 2], dtype=int32), 5, 536)
# (array([1, 2, 1, 2], dtype=int32), 5, 537)
# (array([2, 1, 2, 1], dtype=int32), 6, 538)
# (array([1, 1, 1, 1], dtype=int32), 5, 539)
# (array([2, 2, 2, 2], dtype=int32), 6, 540)
# (array([1, 1, 1, 1], dtype=int32), 4, 541)
# (array([2, 2, 2, 2], dtype=int32), 5, 542)
# (array([1, 2, 1, 2], dtype=int32), 5, 543)
# (array([2, 1, 2, 1], dtype=int32), 6, 544)
# (array([1, 1, 1, 1], dtype=int32), 5, 545)
# (array([2, 2, 2, 2], dtype=int32), 6, 546)
# (array([1, 1, 1, 1], dtype=int32), 4, 547)
# (array([2, 2, 2, 2], dtype=int32), 5, 548)
# (array([1, 2, 1, 2], dtype=int32), 5, 549)
# (array([2, 1, 2, 1], dtype=int32), 6, 550)
# (array([1, 1, 1, 1], dtype=int32), 5, 551)
# (array([2, 2, 2, 2], dtype=int32), 6, 552)
# (array([2, 1, 2, 1], dtype=int32), 6, 553)
# (array([1, 1, 1, 1], dtype=int32), 5, 554)
# (array([2, 2, 2, 2], dtype=int32), 6, 555)
# (array([1, 1, 1, 1], dtype=int32), 4, 556)
# (array([2, 2, 2, 2], dtype=int32), 5, 557)
# (array([1, 2, 1, 2], dtype=int32), 5, 558)
# (array([1, 1, 1, 1], dtype=int32), 4, 559)
# (array([2, 2, 2, 2], dtype=int32), 5, 560)
# (array([1, 2, 1, 2], dtype=int32), 5, 561)
# (array([2, 1, 2, 1], dtype=int32), 6, 562)
# (array([1, 1, 1, 1], dtype=int32), 5, 563)
# (array([2, 2, 2, 2], dtype=int32), 6, 564)
# (array([1, 1, 1, 1], dtype=int32), 4, 565)
# (array([2, 2, 2, 2], dtype=int32), 5, 566)
# (array([1, 2, 1, 2], dtype=int32), 5, 567)
# (array([2, 1, 2, 1], dtype=int32), 6, 568)
# (array([1, 1, 1, 1], dtype=int32), 5, 569)
# (array([2, 2, 2, 2], dtype=int32), 6, 570)
# (array([1, 1, 1, 1], dtype=int32), 4, 571)
# (array([2, 2, 2, 2], dtype=int32), 5, 572)
# (array([1, 2, 1, 2], dtype=int32), 5, 573)
# (array([2, 1, 2, 1], dtype=int32), 6, 574)
# (array([1, 1, 1, 1], dtype=int32), 5, 575)
# (array([2, 2, 2, 2], dtype=int32), 6, 576)
# (array([1, 1, 1, 1], dtype=int32), 4, 577)
# (array([2, 2, 2, 2], dtype=int32), 5, 578)
# (array([1, 2, 1, 2], dtype=int32), 5, 579)
# (array([2, 1, 2, 1], dtype=int32), 6, 580)
# (array([1, 1, 1, 1], dtype=int32), 5, 581)
# (array([2, 2, 2, 2], dtype=int32), 6, 582)
# (array([2, 1, 2, 1], dtype=int32), 6, 583)
# (array([1, 1, 1, 1], dtype=int32), 5, 584)
# (array([2, 2, 2, 2], dtype=int32), 6, 585)
# (array([1, 1, 1, 1], dtype=int32), 4, 586)
# (array([2, 2, 2, 2], dtype=int32), 5, 587)
# (array([1, 2, 1, 2], dtype=int32), 5, 588)
# (array([1, 1, 1, 1], dtype=int32), 4, 589)
# (array([2, 2, 2, 2], dtype=int32), 5, 590)
# (array([1, 2, 1, 2], dtype=int32), 5, 591)
# (array([2, 1, 2, 1], dtype=int32), 6, 592)
# (array([1, 1, 1, 1], dtype=int32), 5, 593)
# (array([2, 2, 2, 2], dtype=int32), 6, 594)
# (array([2, 1, 2, 1], dtype=int32), 6, 595)
# (array([1, 1, 1, 1], dtype=int32), 5, 596)
# (array([2, 2, 2, 2], dtype=int32), 6, 597)
# (array([1, 1, 1, 1], dtype=int32), 4, 598)
# (array([2, 2, 2, 2], dtype=int32), 5, 599)
# (array([1, 2, 1, 2], dtype=int32), 5, 600)
# (array([1, 1, 1, 1], dtype=int32), 4, 601)
# (array([2, 2, 2, 2], dtype=int32), 5, 602)
# (array([1, 2, 1, 2], dtype=int32), 5, 603)
# (array([2, 1, 2, 1], dtype=int32), 6, 604)
# (array([1, 1, 1, 1], dtype=int32), 5, 605)
# (array([2, 2, 2, 2], dtype=int32), 6, 606)
# (array([1, 1, 1, 1], dtype=int32), 4, 607)
# (array([2, 2, 2, 2], dtype=int32), 5, 608)
# (array([1, 2, 1, 2], dtype=int32), 5, 609)
# (array([2, 1, 2, 1], dtype=int32), 6, 610)
# (array([1, 1, 1, 1], dtype=int32), 5, 611)
# (array([2, 2, 2, 2], dtype=int32), 6, 612)
# (array([1, 1, 1, 1], dtype=int32), 4, 613)
# (array([2, 2, 2, 2], dtype=int32), 5, 614)
# (array([1, 2, 1, 2], dtype=int32), 5, 615)
# (array([2, 1, 2, 1], dtype=int32), 6, 616)
# (array([1, 1, 1, 1], dtype=int32), 5, 617)
# (array([2, 2, 2, 2], dtype=int32), 6, 618)
# (array([1, 1, 1, 1], dtype=int32), 4, 619)
# (array([2, 2, 2, 2], dtype=int32), 5, 620)
# (array([1, 2, 1, 2], dtype=int32), 5, 621)
# (array([2, 1, 2, 1], dtype=int32), 6, 622)
# (array([1, 1, 1, 1], dtype=int32), 5, 623)
# (array([2, 2, 2, 2], dtype=int32), 6, 624)
# (array([1, 1, 1, 1], dtype=int32), 4, 625)
# (array([2, 2, 2, 2], dtype=int32), 5, 626)
# (array([1, 2, 1, 2], dtype=int32), 5, 627)
# (array([2, 1, 2, 1], dtype=int32), 6, 628)
# (array([1, 1, 1, 1], dtype=int32), 5, 629)
# (array([2, 2, 2, 2], dtype=int32), 6, 630)
# (array([1, 1, 1, 1], dtype=int32), 4, 631)
# (array([2, 2, 2, 2], dtype=int32), 5, 632)
# (array([1, 2, 1, 2], dtype=int32), 5, 633)
# (array([2, 1, 2, 1], dtype=int32), 6, 634)
# (array([1, 1, 1, 1], dtype=int32), 5, 635)
# (array([2, 2, 2, 2], dtype=int32), 6, 636)
# (array([2, 1, 2, 1], dtype=int32), 6, 637)
# (array([1, 1, 1, 1], dtype=int32), 5, 638)
# (array([2, 2, 2, 2], dtype=int32), 6, 639)
# (array([1, 1, 1, 1], dtype=int32), 4, 640)
# (array([2, 2, 2, 2], dtype=int32), 5, 641)
# (array([1, 2, 1, 2], dtype=int32), 5, 642)
# (array([2, 1, 2, 1], dtype=int32), 6, 643)
# (array([1, 1, 1, 1], dtype=int32), 5, 644)
# (array([2, 2, 2, 2], dtype=int32), 6, 645)
# (array([1, 1, 1, 1], dtype=int32), 4, 646)
# (array([2, 2, 2, 2], dtype=int32), 5, 647)
# (array([1, 2, 1, 2], dtype=int32), 5, 648)
# (array([2, 1, 2, 1], dtype=int32), 6, 649)
# (array([1, 1, 1, 1], dtype=int32), 5, 650)
# (array([2, 2, 2, 2], dtype=int32), 6, 651)
# (array([1, 1, 1, 1], dtype=int32), 4, 652)
# (array([2, 2, 2, 2], dtype=int32), 5, 653)
# (array([1, 2, 1, 2], dtype=int32), 5, 654)
# (array([2, 1, 2, 1], dtype=int32), 6, 655)
# (array([1, 1, 1, 1], dtype=int32), 5, 656)
# (array([2, 2, 2, 2], dtype=int32), 6, 657)
# (array([1, 1, 1, 1], dtype=int32), 4, 658)
# (array([2, 2, 2, 2], dtype=int32), 5, 659)
# (array([1, 2, 1, 2], dtype=int32), 5, 660)
# (array([2, 1, 2, 1], dtype=int32), 6, 661)
# (array([1, 1, 1, 1], dtype=int32), 5, 662)
# (array([2, 2, 2, 2], dtype=int32), 6, 663)
# (array([1, 1, 1, 1], dtype=int32), 4, 664)
# (array([2, 2, 2, 2], dtype=int32), 5, 665)
# (array([1, 2, 1, 2], dtype=int32), 5, 666)
# (array([2, 1, 2, 1], dtype=int32), 6, 667)
# (array([1, 1, 1, 1], dtype=int32), 5, 668)
# (array([2, 2, 2, 2], dtype=int32), 6, 669)
# (array([1, 1, 1, 1], dtype=int32), 4, 670)
# (array([2, 2, 2, 2], dtype=int32), 5, 671)
# (array([1, 2, 1, 2], dtype=int32), 5, 672)
# (array([1, 1, 1, 1], dtype=int32), 4, 673)
# (array([2, 2, 2, 2], dtype=int32), 5, 674)
# (array([1, 2, 1, 2], dtype=int32), 5, 675)
# (array([2, 1, 2, 1], dtype=int32), 6, 676)
# (array([1, 1, 1, 1], dtype=int32), 5, 677)
# (array([2, 2, 2, 2], dtype=int32), 6, 678)
# (array([2, 1, 2, 1], dtype=int32), 6, 679)
# (array([1, 1, 1, 1], dtype=int32), 5, 680)
# (array([2, 2, 2, 2], dtype=int32), 6, 681)
# (array([1, 1, 1, 1], dtype=int32), 4, 682)
# (array([2, 2, 2, 2], dtype=int32), 5, 683)
# (array([1, 2, 1, 2], dtype=int32), 5, 684)
# (array([1, 1, 1, 1], dtype=int32), 4, 685)
# (array([2, 2, 2, 2], dtype=int32), 5, 686)
# (array([1, 2, 1, 2], dtype=int32), 5, 687)
# (array([2, 1, 2, 1], dtype=int32), 6, 688)
# (array([1, 1, 1, 1], dtype=int32), 5, 689)
# (array([2, 2, 2, 2], dtype=int32), 6, 690)
# (array([1, 1, 1, 1], dtype=int32), 4, 691)
# (array([2, 2, 2, 2], dtype=int32), 5, 692)
# (array([1, 2, 1, 2], dtype=int32), 5, 693)
# (array([2, 1, 2, 1], dtype=int32), 6, 694)
# (array([1, 1, 1, 1], dtype=int32), 5, 695)
# (array([2, 2, 2, 2], dtype=int32), 6, 696)
# (array([2, 1, 2, 1], dtype=int32), 6, 697)
# (array([1, 1, 1, 1], dtype=int32), 5, 698)
# (array([2, 2, 2, 2], dtype=int32), 6, 699)
# (array([1, 1, 1, 1], dtype=int32), 4, 700)
# (array([2, 2, 2, 2], dtype=int32), 5, 701)
# (array([1, 2, 1, 2], dtype=int32), 5, 702)
# (array([2, 1, 2, 1], dtype=int32), 6, 703)
# (array([1, 1, 1, 1], dtype=int32), 5, 704)
# (array([2, 2, 2, 2], dtype=int32), 6, 705)
# (array([1, 1, 1, 1], dtype=int32), 4, 706)
# (array([2, 2, 2, 2], dtype=int32), 5, 707)
# (array([1, 2, 1, 2], dtype=int32), 5, 708)
# (array([2, 1, 2, 1], dtype=int32), 6, 709)
# (array([1, 1, 1, 1], dtype=int32), 5, 710)
# (array([2, 2, 2, 2], dtype=int32), 6, 711)
# (array([1, 1, 1, 1], dtype=int32), 4, 712)
# (array([2, 2, 2, 2], dtype=int32), 5, 713)
# (array([1, 2, 1, 2], dtype=int32), 5, 714)
# (array([1, 1, 1, 1], dtype=int32), 4, 715)
# (array([2, 2, 2, 2], dtype=int32), 5, 716)
# (array([1, 2, 1, 2], dtype=int32), 5, 717)
# (array([2, 1, 2, 1], dtype=int32), 6, 718)
# (array([1, 1, 1, 1], dtype=int32), 5, 719)
# (array([2, 2, 2, 2], dtype=int32), 6, 720)
# (array([1, 1, 1, 1], dtype=int32), 4, 721)
# (array([2, 2, 2, 2], dtype=int32), 5, 722)
# (array([1, 2, 1, 2], dtype=int32), 5, 723)
# (array([2, 1, 2, 1], dtype=int32), 6, 724)
# (array([1, 1, 1, 1], dtype=int32), 5, 725)
# (array([2, 2, 2, 2], dtype=int32), 6, 726)
# (array([2, 1, 2, 1], dtype=int32), 6, 727)
# (array([1, 1, 1, 1], dtype=int32), 5, 728)
# (array([2, 2, 2, 2], dtype=int32), 6, 729)
# (array([1, 1, 1, 1], dtype=int32), 4, 730)
# (array([2, 2, 2, 2], dtype=int32), 5, 731)
# (array([1, 2, 1, 2], dtype=int32), 5, 732)
# (array([2, 1, 2, 1], dtype=int32), 6, 733)
# (array([1, 1, 1, 1], dtype=int32), 5, 734)
# (array([2, 2, 2, 2], dtype=int32), 6, 735)
# (array([1, 1, 1, 1], dtype=int32), 4, 736)
# (array([2, 2, 2, 2], dtype=int32), 5, 737)
# (array([1, 2, 1, 2], dtype=int32), 5, 738)
# (array([2, 1, 2, 1], dtype=int32), 6, 739)
# (array([1, 1, 1, 1], dtype=int32), 5, 740)
# (array([2, 2, 2, 2], dtype=int32), 6, 741)
# (array([1, 1, 1, 1], dtype=int32), 4, 742)
# (array([2, 2, 2, 2], dtype=int32), 5, 743)
# (array([1, 2, 1, 2], dtype=int32), 5, 744)
# (array([2, 1, 2, 1], dtype=int32), 6, 745)
# (array([1, 1, 1, 1], dtype=int32), 5, 746)
# (array([2, 2, 2, 2], dtype=int32), 6, 747)
# (array([1, 1, 1, 1], dtype=int32), 4, 748)
# (array([2, 2, 2, 2], dtype=int32), 5, 749)
# (array([1, 2, 1, 2], dtype=int32), 5, 750)
# (array([2, 1, 2, 1], dtype=int32), 6, 751)
# (array([1, 1, 1, 1], dtype=int32), 5, 752)
# (array([2, 2, 2, 2], dtype=int32), 6, 753)
# (array([1, 1, 1, 1], dtype=int32), 4, 754)
# (array([2, 2, 2, 2], dtype=int32), 5, 755)
# (array([1, 2, 1, 2], dtype=int32), 5, 756)
# (array([2, 1, 2, 1], dtype=int32), 6, 757)
# (array([1, 1, 1, 1], dtype=int32), 5, 758)
# (array([2, 2, 2, 2], dtype=int32), 6, 759)
# (array([1, 1, 1, 1], dtype=int32), 4, 760)
# (array([2, 2, 2, 2], dtype=int32), 5, 761)
# (array([1, 2, 1, 2], dtype=int32), 5, 762)
# (array([1, 1, 1, 1], dtype=int32), 4, 763)
# (array([2, 2, 2, 2], dtype=int32), 5, 764)
# (array([1, 2, 1, 2], dtype=int32), 5, 765)
# (array([2, 1, 2, 1], dtype=int32), 6, 766)
# (array([1, 1, 1, 1], dtype=int32), 5, 767)
# (array([2, 2, 2, 2], dtype=int32), 6, 768)
# (array([1, 1, 1, 1], dtype=int32), 4, 769)
# (array([2, 2, 2, 2], dtype=int32), 5, 770)
# (array([1, 2, 1, 2], dtype=int32), 5, 771)
# (array([2, 1, 2, 1], dtype=int32), 6, 772)
# (array([1, 1, 1, 1], dtype=int32), 5, 773)
# (array([2, 2, 2, 2], dtype=int32), 6, 774)
# (array([1, 1, 1, 1], dtype=int32), 4, 775)
# (array([2, 2, 2, 2], dtype=int32), 5, 776)
# (array([1, 2, 1, 2], dtype=int32), 5, 777)
# (array([2, 1, 2, 1], dtype=int32), 6, 778)
# (array([1, 1, 1, 1], dtype=int32), 5, 779)
# (array([2, 2, 2, 2], dtype=int32), 6, 780)
# (array([2, 1, 2, 1], dtype=int32), 6, 781)
# (array([1, 1, 1, 1], dtype=int32), 5, 782)
# (array([2, 2, 2, 2], dtype=int32), 6, 783)
# (array([1, 1, 1, 1], dtype=int32), 4, 784)
# (array([2, 2, 2, 2], dtype=int32), 5, 785)
# (array([1, 2, 1, 2], dtype=int32), 5, 786)
# (array([2, 1, 2, 1], dtype=int32), 6, 787)
# (array([1, 1, 1, 1], dtype=int32), 5, 788)
# (array([2, 2, 2, 2], dtype=int32), 6, 789)
# (array([1, 1, 1, 1], dtype=int32), 4, 790)
# (array([2, 2, 2, 2], dtype=int32), 5, 791)
# (array([1, 2, 1, 2], dtype=int32), 5, 792)
# (array([2, 1, 2, 1], dtype=int32), 6, 793)
# (array([1, 1, 1, 1], dtype=int32), 5, 794)
# (array([2, 2, 2, 2], dtype=int32), 6, 795)
# (array([1, 1, 1, 1], dtype=int32), 4, 796)
# (array([2, 2, 2, 2], dtype=int32), 5, 797)
# (array([1, 2, 1, 2], dtype=int32), 5, 798)
# (array([2, 1, 2, 1], dtype=int32), 6, 799)
# (array([1, 1, 1, 1], dtype=int32), 5, 800)
# (array([2, 2, 2, 2], dtype=int32), 6, 801)
# (array([1, 1, 1, 1], dtype=int32), 4, 802)
# (array([2, 2, 2, 2], dtype=int32), 5, 803)
# (array([1, 2, 1, 2], dtype=int32), 5, 804)
# (array([2, 1, 2, 1], dtype=int32), 6, 805)
# (array([1, 1, 1, 1], dtype=int32), 5, 806)
# (array([2, 2, 2, 2], dtype=int32), 6, 807)
# (array([1, 1, 1, 1], dtype=int32), 4, 808)
# (array([2, 2, 2, 2], dtype=int32), 5, 809)
# (array([1, 2, 1, 2], dtype=int32), 5, 810)
# (array([1, 1, 1, 1], dtype=int32), 4, 811)
# (array([2, 2, 2, 2], dtype=int32), 5, 812)
# (array([1, 2, 1, 2], dtype=int32), 5, 813)
# (array([2, 1, 2, 1], dtype=int32), 6, 814)
# (array([1, 1, 1, 1], dtype=int32), 5, 815)
# (array([2, 2, 2, 2], dtype=int32), 6, 816)
# (array([1, 1, 1, 1], dtype=int32), 4, 817)
# (array([2, 2, 2, 2], dtype=int32), 5, 818)
# (array([1, 2, 1, 2], dtype=int32), 5, 819)
# (array([2, 1, 2, 1], dtype=int32), 6, 820)
# (array([1, 1, 1, 1], dtype=int32), 5, 821)
# (array([2, 2, 2, 2], dtype=int32), 6, 822)
# (array([2, 1, 2, 1], dtype=int32), 6, 823)
# (array([1, 1, 1, 1], dtype=int32), 5, 824)
# (array([2, 2, 2, 2], dtype=int32), 6, 825)
# (array([1, 1, 1, 1], dtype=int32), 4, 826)
# (array([2, 2, 2, 2], dtype=int32), 5, 827)
# (array([1, 2, 1, 2], dtype=int32), 5, 828)
# (array([1, 1, 1, 1], dtype=int32), 4, 829)
# (array([2, 2, 2, 2], dtype=int32), 5, 830)
# (array([1, 2, 1, 2], dtype=int32), 5, 831)
# (array([2, 1, 2, 1], dtype=int32), 6, 832)
# (array([1, 1, 1, 1], dtype=int32), 5, 833)
# (array([2, 2, 2, 2], dtype=int32), 6, 834)
# (array([2, 1, 2, 1], dtype=int32), 6, 835)
# (array([1, 1, 1, 1], dtype=int32), 5, 836)
# (array([2, 2, 2, 2], dtype=int32), 6, 837)
# (array([1, 1, 1, 1], dtype=int32), 4, 838)
# (array([2, 2, 2, 2], dtype=int32), 5, 839)
# (array([1, 2, 1, 2], dtype=int32), 5, 840)
# (array([2, 1, 2, 1], dtype=int32), 6, 841)
# (array([1, 1, 1, 1], dtype=int32), 5, 842)
# (array([2, 2, 2, 2], dtype=int32), 6, 843)
# (array([1, 1, 1, 1], dtype=int32), 4, 844)
# (array([2, 2, 2, 2], dtype=int32), 5, 845)
# (array([1, 2, 1, 2], dtype=int32), 5, 846)
# (array([1, 1, 1, 1], dtype=int32), 4, 847)
# (array([2, 2, 2, 2], dtype=int32), 5, 848)
# (array([1, 2, 1, 2], dtype=int32), 5, 849)
# (array([2, 1, 2, 1], dtype=int32), 6, 850)
# (array([1, 1, 1, 1], dtype=int32), 5, 851)
# (array([2, 2, 2, 2], dtype=int32), 6, 852)
# (array([2, 1, 2, 1], dtype=int32), 6, 853)
# (array([1, 1, 1, 1], dtype=int32), 5, 854)
# (array([2, 2, 2, 2], dtype=int32), 6, 855)
# (array([1, 1, 1, 1], dtype=int32), 4, 856)
# (array([2, 2, 2, 2], dtype=int32), 5, 857)
# (array([1, 2, 1, 2], dtype=int32), 5, 858)
# (array([1, 1, 1, 1], dtype=int32), 4, 859)
# (array([2, 2, 2, 2], dtype=int32), 5, 860)
# (array([1, 2, 1, 2], dtype=int32), 5, 861)
# (array([2, 1, 2, 1], dtype=int32), 6, 862)
# (array([1, 1, 1, 1], dtype=int32), 5, 863)
# (array([2, 2, 2, 2], dtype=int32), 6, 864)
# (array([2, 1, 2, 1], dtype=int32), 6, 865)
# (array([1, 1, 1, 1], dtype=int32), 5, 866)
# (array([2, 2, 2, 2], dtype=int32), 6, 867)
# (array([1, 1, 1, 1], dtype=int32), 4, 868)
# (array([2, 2, 2, 2], dtype=int32), 5, 869)
# (array([1, 2, 1, 2], dtype=int32), 5, 870)
# (array([1, 1, 1, 1], dtype=int32), 4, 871)
# (array([2, 2, 2, 2], dtype=int32), 5, 872)
# (array([1, 2, 1, 2], dtype=int32), 5, 873)
# (array([2, 1, 2, 1], dtype=int32), 6, 874)
# (array([1, 1, 1, 1], dtype=int32), 5, 875)
# (array([2, 2, 2, 2], dtype=int32), 6, 876)
# (array([1, 1, 1, 1], dtype=int32), 4, 877)
# (array([2, 2, 2, 2], dtype=int32), 5, 878)
# (array([1, 2, 1, 2], dtype=int32), 5, 879)
# (array([2, 1, 2, 1], dtype=int32), 6, 880)
# (array([1, 1, 1, 1], dtype=int32), 5, 881)
# (array([2, 2, 2, 2], dtype=int32), 6, 882)
# (array([2, 1, 2, 1], dtype=int32), 6, 883)
# (array([1, 1, 1, 1], dtype=int32), 5, 884)
# (array([2, 2, 2, 2], dtype=int32), 6, 885)
# (array([1, 1, 1, 1], dtype=int32), 4, 886)
# (array([2, 2, 2, 2], dtype=int32), 5, 887)
# (array([1, 2, 1, 2], dtype=int32), 5, 888)
# (array([2, 1, 2, 1], dtype=int32), 6, 889)
# (array([1, 1, 1, 1], dtype=int32), 5, 890)
# (array([2, 2, 2, 2], dtype=int32), 6, 891)
# (array([1, 1, 1, 1], dtype=int32), 4, 892)
# (array([2, 2, 2, 2], dtype=int32), 5, 893)
# (array([1, 2, 1, 2], dtype=int32), 5, 894)
# (array([1, 1, 1, 1], dtype=int32), 4, 895)
# (array([2, 2, 2, 2], dtype=int32), 5, 896)
# (array([1, 2, 1, 2], dtype=int32), 5, 897)
# (array([2, 1, 2, 1], dtype=int32), 6, 898)
# (array([1, 1, 1, 1], dtype=int32), 5, 899)
# (array([2, 2, 2, 2], dtype=int32), 6, 900)
# (array([1, 1, 1, 1], dtype=int32), 4, 901)
# (array([2, 2, 2, 2], dtype=int32), 5, 902)
# (array([1, 2, 1, 2], dtype=int32), 5, 903)
# (array([2, 1, 2, 1], dtype=int32), 6, 904)
# (array([1, 1, 1, 1], dtype=int32), 5, 905)
# (array([2, 2, 2, 2], dtype=int32), 6, 906)
# (array([2, 1, 2, 1], dtype=int32), 6, 907)
# (array([1, 1, 1, 1], dtype=int32), 5, 908)
# (array([2, 2, 2, 2], dtype=int32), 6, 909)
# (array([1, 1, 1, 1], dtype=int32), 4, 910)
# (array([2, 2, 2, 2], dtype=int32), 5, 911)
# (array([1, 2, 1, 2], dtype=int32), 5, 912)
# (array([2, 1, 2, 1], dtype=int32), 6, 913)
# (array([1, 1, 1, 1], dtype=int32), 5, 914)
# (array([2, 2, 2, 2], dtype=int32), 6, 915)
# (array([1, 1, 1, 1], dtype=int32), 4, 916)
# (array([2, 2, 2, 2], dtype=int32), 5, 917)
# (array([1, 2, 1, 2], dtype=int32), 5, 918)
# (array([1, 1, 1, 1], dtype=int32), 4, 919)
# (array([2, 2, 2, 2], dtype=int32), 5, 920)
# (array([1, 2, 1, 2], dtype=int32), 5, 921)
# (array([2, 1, 2, 1], dtype=int32), 6, 922)
# (array([1, 1, 1, 1], dtype=int32), 5, 923)
# (array([2, 2, 2, 2], dtype=int32), 6, 924)
# (array([1, 1, 1, 1], dtype=int32), 4, 925)
# (array([2, 2, 2, 2], dtype=int32), 5, 926)
# (array([1, 2, 1, 2], dtype=int32), 5, 927)
# (array([2, 1, 2, 1], dtype=int32), 6, 928)
# (array([1, 1, 1, 1], dtype=int32), 5, 929)
# (array([2, 2, 2, 2], dtype=int32), 6, 930)
# (array([2, 1, 2, 1], dtype=int32), 6, 931)
# (array([1, 1, 1, 1], dtype=int32), 5, 932)
# (array([2, 2, 2, 2], dtype=int32), 6, 933)
# (array([1, 1, 1, 1], dtype=int32), 4, 934)
# (array([2, 2, 2, 2], dtype=int32), 5, 935)
# (array([1, 2, 1, 2], dtype=int32), 5, 936)
# (array([2, 1, 2, 1], dtype=int32), 6, 937)
# (array([1, 1, 1, 1], dtype=int32), 5, 938)
# (array([2, 2, 2, 2], dtype=int32), 6, 939)
# (array([1, 1, 1, 1], dtype=int32), 4, 940)
# (array([2, 2, 2, 2], dtype=int32), 5, 941)
# (array([1, 2, 1, 2], dtype=int32), 5, 942)
# (array([1, 1, 1, 1], dtype=int32), 4, 943)
# (array([2, 2, 2, 2], dtype=int32), 5, 944)
# (array([1, 2, 1, 2], dtype=int32), 5, 945)
# (array([2, 1, 2, 1], dtype=int32), 6, 946)
# (array([1, 1, 1, 1], dtype=int32), 5, 947)
# (array([2, 2, 2, 2], dtype=int32), 6, 948)
# (array([1, 1, 1, 1], dtype=int32), 4, 949)
# (array([2, 2, 2, 2], dtype=int32), 5, 950)
# (array([1, 2, 1, 2], dtype=int32), 5, 951)
# (array([2, 1, 2, 1], dtype=int32), 6, 952)
# (array([1, 1, 1, 1], dtype=int32), 5, 953)
# (array([2, 2, 2, 2], dtype=int32), 6, 954)
# (array([1, 1, 1, 1], dtype=int32), 4, 955)
# (array([2, 2, 2, 2], dtype=int32), 5, 956)
# (array([1, 2, 1, 2], dtype=int32), 5, 957)
# (array([2, 1, 2, 1], dtype=int32), 6, 958)
# (array([1, 1, 1, 1], dtype=int32), 5, 959)
# (array([2, 2, 2, 2], dtype=int32), 6, 960)
# (array([1, 1, 1, 1], dtype=int32), 4, 961)
# (array([2, 2, 2, 2], dtype=int32), 5, 962)
# (array([1, 2, 1, 2], dtype=int32), 5, 963)
# (array([2, 1, 2, 1], dtype=int32), 6, 964)
# (array([1, 1, 1, 1], dtype=int32), 5, 965)
# (array([2, 2, 2, 2], dtype=int32), 6, 966)
# (array([1, 1, 1, 1], dtype=int32), 4, 967)
# (array([2, 2, 2, 2], dtype=int32), 5, 968)
# (array([1, 2, 1, 2], dtype=int32), 5, 969)
# (array([2, 1, 2, 1], dtype=int32), 6, 970)
# (array([1, 1, 1, 1], dtype=int32), 5, 971)
# (array([2, 2, 2, 2], dtype=int32), 6, 972)
# (array([1, 1, 1, 1], dtype=int32), 4, 973)
# (array([2, 2, 2, 2], dtype=int32), 5, 974)
# (array([1, 2, 1, 2], dtype=int32), 5, 975)
# (array([2, 1, 2, 1], dtype=int32), 6, 976)
# (array([1, 1, 1, 1], dtype=int32), 5, 977)
# (array([2, 2, 2, 2], dtype=int32), 6, 978)
# (array([1, 1, 1, 1], dtype=int32), 4, 979)
# (array([2, 2, 2, 2], dtype=int32), 5, 980)
# (array([1, 2, 1, 2], dtype=int32), 5, 981)
# (array([2, 1, 2, 1], dtype=int32), 6, 982)
# (array([1, 1, 1, 1], dtype=int32), 5, 983)
# (array([2, 2, 2, 2], dtype=int32), 6, 984)
# (array([2, 1, 2, 1], dtype=int32), 6, 985)
# (array([1, 1, 1, 1], dtype=int32), 5, 986)
# (array([2, 2, 2, 2], dtype=int32), 6, 987)
# (array([1, 1, 1, 1], dtype=int32), 4, 988)
# (array([2, 2, 2, 2], dtype=int32), 5, 989)
# (array([1, 2, 1, 2], dtype=int32), 5, 990)
# (array([1, 1, 1, 1], dtype=int32), 4, 991)
# (array([2, 2, 2, 2], dtype=int32), 5, 992)
# (array([1, 2, 1, 2], dtype=int32), 5, 993)
# (array([2, 1, 2, 1], dtype=int32), 6, 994)
# (array([1, 1, 1, 1], dtype=int32), 5, 995)
# (array([2, 2, 2, 2], dtype=int32), 6, 996)
# (array([1, 1, 1, 1], dtype=int32), 4, 997)
# (array([2, 2, 2, 2], dtype=int32), 5, 998)
# (array([1, 2, 1, 2], dtype=int32), 5, 999)
# (array([2, 1, 2, 1], dtype=int32), 6, 1000)
# (array([1, 1, 1, 1], dtype=int32), 5, 1001)
# (array([2, 2, 2, 2], dtype=int32), 6, 1002)
# (array([2, 1, 2, 1], dtype=int32), 6, 1003)
# (array([1, 1, 1, 1], dtype=int32), 5, 1004)
# (array([2, 2, 2, 2], dtype=int32), 6, 1005)
# (array([1, 1, 1, 1], dtype=int32), 4, 1006)
# (array([2, 2, 2, 2], dtype=int32), 5, 1007)
# (array([1, 2, 1, 2], dtype=int32), 5, 1008)
# (array([1, 1, 1, 1], dtype=int32), 4, 1009)
# (array([2, 2, 2, 2], dtype=int32), 5, 1010)
# (array([1, 2, 1, 2], dtype=int32), 5, 1011)
# (array([2, 1, 2, 1], dtype=int32), 6, 1012)
# (array([1, 1, 1, 1], dtype=int32), 5, 1013)
# (array([2, 2, 2, 2], dtype=int32), 6, 1014)
# (array([1, 1, 1, 1], dtype=int32), 4, 1015)
# (array([2, 2, 2, 2], dtype=int32), 5, 1016)
# (array([1, 2, 1, 2], dtype=int32), 5, 1017)
# (array([2, 1, 2, 1], dtype=int32), 6, 1018)
# (array([1, 1, 1, 1], dtype=int32), 5, 1019)
# (array([2, 2, 2, 2], dtype=int32), 6, 1020)
# (array([1, 1, 1, 1], dtype=int32), 4, 1021)
# (array([2, 2, 2, 2], dtype=int32), 5, 1022)
# (array([1, 2, 1, 2], dtype=int32), 5, 1023)
# (array([2, 1, 2, 1], dtype=int32), 6, 1024)
# (array([1, 1, 1, 1], dtype=int32), 5, 1025)
# (array([2, 2, 2, 2], dtype=int32), 6, 1026)
# (array([2, 1, 2, 1], dtype=int32), 6, 1027)
# (array([1, 1, 1, 1], dtype=int32), 5, 1028)
# (array([2, 2, 2, 2], dtype=int32), 6, 1029)
# (array([1, 1, 1, 1], dtype=int32), 4, 1030)
# (array([2, 2, 2, 2], dtype=int32), 5, 1031)
# (array([1, 2, 1, 2], dtype=int32), 5, 1032)
# (array([2, 1, 2, 1], dtype=int32), 6, 1033)
# (array([1, 1, 1, 1], dtype=int32), 5, 1034)
# (array([2, 2, 2, 2], dtype=int32), 6, 1035)
# (array([1, 1, 1, 1], dtype=int32), 4, 1036)
# (array([2, 2, 2, 2], dtype=int32), 5, 1037)
# (array([1, 2, 1, 2], dtype=int32), 5, 1038)
# (array([2, 1, 2, 1], dtype=int32), 6, 1039)
# (array([1, 1, 1, 1], dtype=int32), 5, 1040)
# (array([2, 2, 2, 2], dtype=int32), 6, 1041)
# (array([1, 1, 1, 1], dtype=int32), 4, 1042)
# (array([2, 2, 2, 2], dtype=int32), 5, 1043)
# (array([1, 2, 1, 2], dtype=int32), 5, 1044)
# (array([1, 1, 1, 1], dtype=int32), 4, 1045)
# (array([2, 2, 2, 2], dtype=int32), 5, 1046)
# (array([1, 2, 1, 2], dtype=int32), 5, 1047)
# (array([2, 1, 2, 1], dtype=int32), 6, 1048)
# (array([1, 1, 1, 1], dtype=int32), 5, 1049)
# (array([2, 2, 2, 2], dtype=int32), 6, 1050)
# (array([2, 1, 2, 1], dtype=int32), 6, 1051)
# (array([1, 1, 1, 1], dtype=int32), 5, 1052)
# (array([2, 2, 2, 2], dtype=int32), 6, 1053)
# (array([1, 1, 1, 1], dtype=int32), 4, 1054)
# (array([2, 2, 2, 2], dtype=int32), 5, 1055)
# (array([1, 2, 1, 2], dtype=int32), 5, 1056)
# (array([2, 1, 2, 1], dtype=int32), 6, 1057)
# (array([1, 1, 1, 1], dtype=int32), 5, 1058)
# (array([2, 2, 2, 2], dtype=int32), 6, 1059)
# (array([1, 1, 1, 1], dtype=int32), 4, 1060)
# (array([2, 2, 2, 2], dtype=int32), 5, 1061)
# (array([1, 2, 1, 2], dtype=int32), 5, 1062)
# (array([2, 1, 2, 1], dtype=int32), 6, 1063)
# (array([1, 1, 1, 1], dtype=int32), 5, 1064)
# (array([2, 2, 2, 2], dtype=int32), 6, 1065)
# (array([1, 1, 1, 1], dtype=int32), 4, 1066)
# (array([2, 2, 2, 2], dtype=int32), 5, 1067)
# (array([1, 2, 1, 2], dtype=int32), 5, 1068)
# (array([2, 1, 2, 1], dtype=int32), 6, 1069)
# (array([1, 1, 1, 1], dtype=int32), 5, 1070)
# (array([2, 2, 2, 2], dtype=int32), 6, 1071)
# (array([1, 1, 1, 1], dtype=int32), 4, 1072)
# (array([2, 2, 2, 2], dtype=int32), 5, 1073)
# (array([1, 2, 1, 2], dtype=int32), 5, 1074)
# (array([1, 1, 1, 1], dtype=int32), 4, 1075)
# (array([2, 2, 2, 2], dtype=int32), 5, 1076)
# (array([1, 2, 1, 2], dtype=int32), 5, 1077)
# (array([2, 1, 2, 1], dtype=int32), 6, 1078)
# (array([1, 1, 1, 1], dtype=int32), 5, 1079)
# (array([2, 2, 2, 2], dtype=int32), 6, 1080)
# (array([2, 1, 2, 1], dtype=int32), 6, 1081)
# (array([1, 1, 1, 1], dtype=int32), 5, 1082)
# (array([2, 2, 2, 2], dtype=int32), 6, 1083)
# (array([1, 1, 1, 1], dtype=int32), 4, 1084)
# (array([2, 2, 2, 2], dtype=int32), 5, 1085)
# (array([1, 2, 1, 2], dtype=int32), 5, 1086)
# (array([1, 1, 1, 1], dtype=int32), 4, 1087)
# (array([2, 2, 2, 2], dtype=int32), 5, 1088)
# (array([1, 2, 1, 2], dtype=int32), 5, 1089)
# (array([2, 1, 2, 1], dtype=int32), 6, 1090)
# (array([1, 1, 1, 1], dtype=int32), 5, 1091)
# (array([2, 2, 2, 2], dtype=int32), 6, 1092)
# (array([1, 1, 1, 1], dtype=int32), 4, 1093)
# (array([2, 2, 2, 2], dtype=int32), 5, 1094)
# (array([1, 2, 1, 2], dtype=int32), 5, 1095)
# (array([2, 1, 2, 1], dtype=int32), 6, 1096)
# (array([1, 1, 1, 1], dtype=int32), 5, 1097)
# (array([2, 2, 2, 2], dtype=int32), 6, 1098)
# (array([2, 1, 2, 1], dtype=int32), 6, 1099)
# (array([1, 1, 1, 1], dtype=int32), 5, 1100)
# (array([2, 2, 2, 2], dtype=int32), 6, 1101)
# (array([1, 1, 1, 1], dtype=int32), 4, 1102)
# (array([2, 2, 2, 2], dtype=int32), 5, 1103)
# (array([1, 2, 1, 2], dtype=int32), 5, 1104)
# (array([2, 1, 2, 1], dtype=int32), 6, 1105)
# (array([1, 1, 1, 1], dtype=int32), 5, 1106)
# (array([2, 2, 2, 2], dtype=int32), 6, 1107)
# (array([1, 1, 1, 1], dtype=int32), 4, 1108)
# (array([2, 2, 2, 2], dtype=int32), 5, 1109)
# (array([1, 2, 1, 2], dtype=int32), 5, 1110)
# (array([1, 1, 1, 1], dtype=int32), 4, 1111)
# (array([2, 2, 2, 2], dtype=int32), 5, 1112)
# (array([1, 2, 1, 2], dtype=int32), 5, 1113)
# (array([2, 1, 2, 1], dtype=int32), 6, 1114)
# (array([1, 1, 1, 1], dtype=int32), 5, 1115)
# (array([2, 2, 2, 2], dtype=int32), 6, 1116)
# ...
# (array([1, 1, 1, 1], dtype=int32), 5, 33854)
# (array([2, 2, 2, 2], dtype=int32), 6, 33855)
# (array([1, 1, 1, 1], dtype=int32), 4, 33856)
# (array([2, 2, 2, 2], dtype=int32), 5, 33857)
# (array([1, 2, 1, 2], dtype=int32), 5, 33858)
# (array([1, 1, 1, 1], dtype=int32), 4, 33859)
# (array([2, 2, 2, 2], dtype=int32), 5, 33860)
# (array([1, 2, 1, 2], dtype=int32), 5, 33861)
# (array([2, 1, 2, 1], dtype=int32), 6, 33862)
# (array([1, 1, 1, 1], dtype=int32), 5, 33863)
# (array([2, 2, 2, 2], dtype=int32), 6, 33864)
# (array([2, 1, 2, 1], dtype=int32), 6, 33865)
# (array([1, 1, 1, 1], dtype=int32), 5, 33866)
# (array([2, 2, 2, 2], dtype=int32), 6, 33867)
# (array([1, 1, 1, 1], dtype=int32), 4, 33868)
# (array([2, 2, 2, 2], dtype=int32), 5, 33869)
# (array([1, 2, 1, 2], dtype=int32), 5, 33870)
# (array([2, 1, 2, 1], dtype=int32), 6, 33871)
# (array([1, 1, 1, 1], dtype=int32), 5, 33872)
# (array([2, 2, 2, 2], dtype=int32), 6, 33873)
# (array([1, 1, 1, 1], dtype=int32), 4, 33874)
# (array([2, 2, 2, 2], dtype=int32), 5, 33875)
# (array([1, 2, 1, 2], dtype=int32), 5, 33876)
# (array([2, 1, 2, 1], dtype=int32), 6, 33877)
# (array([1, 1, 1, 1], dtype=int32), 5, 33878)
# (array([2, 2, 2, 2], dtype=int32), 6, 33879)
# (array([1, 1, 1, 1], dtype=int32), 4, 33880)
# (array([2, 2, 2, 2], dtype=int32), 5, 33881)
# (array([1, 2, 1, 2], dtype=int32), 5, 33882)
# (array([1, 1, 1, 1], dtype=int32), 4, 33883)
# (array([2, 2, 2, 2], dtype=int32), 5, 33884)
# (array([1, 2, 1, 2], dtype=int32), 5, 33885)
# (array([2, 1, 2, 1], dtype=int32), 6, 33886)
# (array([1, 1, 1, 1], dtype=int32), 5, 33887)
# (array([2, 2, 2, 2], dtype=int32), 6, 33888)
# (array([2, 1, 2, 1], dtype=int32), 6, 33889)
# (array([1, 1, 1, 1], dtype=int32), 5, 33890)
# (array([2, 2, 2, 2], dtype=int32), 6, 33891)
# (array([1, 1, 1, 1], dtype=int32), 4, 33892)
# (array([2, 2, 2, 2], dtype=int32), 5, 33893)
# (array([1, 2, 1, 2], dtype=int32), 5, 33894)
# (array([2, 1, 2, 1], dtype=int32), 6, 33895)
# (array([1, 1, 1, 1], dtype=int32), 5, 33896)
# (array([2, 2, 2, 2], dtype=int32), 6, 33897)
# (array([1, 1, 1, 1], dtype=int32), 4, 33898)
# (array([2, 2, 2, 2], dtype=int32), 5, 33899)
# (array([1, 2, 1, 2], dtype=int32), 5, 33900)
# (array([2, 1, 2, 1], dtype=int32), 6, 33901)
# (array([1, 1, 1, 1], dtype=int32), 5, 33902)
# (array([2, 2, 2, 2], dtype=int32), 6, 33903)
# (array([1, 1, 1, 1], dtype=int32), 4, 33904)
# (array([2, 2, 2, 2], dtype=int32), 5, 33905)
# (array([1, 2, 1, 2], dtype=int32), 5, 33906)
# (array([2, 1, 2, 1], dtype=int32), 6, 33907)
# (array([1, 1, 1, 1], dtype=int32), 5, 33908)
# (array([2, 2, 2, 2], dtype=int32), 6, 33909)
# (array([1, 1, 1, 1], dtype=int32), 4, 33910)
# (array([2, 2, 2, 2], dtype=int32), 5, 33911)
# (array([1, 2, 1, 2], dtype=int32), 5, 33912)
# (array([2, 1, 2, 1], dtype=int32), 6, 33913)
# (array([1, 1, 1, 1], dtype=int32), 5, 33914)
# (array([2, 2, 2, 2], dtype=int32), 6, 33915)
# (array([1, 1, 1, 1], dtype=int32), 4, 33916)
# (array([2, 2, 2, 2], dtype=int32), 5, 33917)
# (array([1, 2, 1, 2], dtype=int32), 5, 33918)
# (array([1, 1, 1, 1], dtype=int32), 4, 33919)
# (array([2, 2, 2, 2], dtype=int32), 5, 33920)
# (array([1, 2, 1, 2], dtype=int32), 5, 33921)
# (array([2, 1, 2, 1], dtype=int32), 6, 33922)
# (array([1, 1, 1, 1], dtype=int32), 5, 33923)
# (array([2, 2, 2, 2], dtype=int32), 6, 33924)
# (array([1, 1, 1, 1], dtype=int32), 4, 33925)
# (array([2, 2, 2, 2], dtype=int32), 5, 33926)
# (array([1, 2, 1, 2], dtype=int32), 5, 33927)
# (array([2, 1, 2, 1], dtype=int32), 6, 33928)
# (array([1, 1, 1, 1], dtype=int32), 5, 33929)
# (array([2, 2, 2, 2], dtype=int32), 6, 33930)
# (array([2, 1, 2, 1], dtype=int32), 6, 33931)
# (array([1, 1, 1, 1], dtype=int32), 5, 33932)
# (array([2, 2, 2, 2], dtype=int32), 6, 33933)
# (array([1, 1, 1, 1], dtype=int32), 4, 33934)
# (array([2, 2, 2, 2], dtype=int32), 5, 33935)
# (array([1, 2, 1, 2], dtype=int32), 5, 33936)
# (array([2, 1, 2, 1], dtype=int32), 6, 33937)
# (array([1, 1, 1, 1], dtype=int32), 5, 33938)
# (array([2, 2, 2, 2], dtype=int32), 6, 33939)
# (array([1, 1, 1, 1], dtype=int32), 4, 33940)
# (array([2, 2, 2, 2], dtype=int32), 5, 33941)
# (array([1, 2, 1, 2], dtype=int32), 5, 33942)
# (array([2, 1, 2, 1], dtype=int32), 6, 33943)
# (array([1, 1, 1, 1], dtype=int32), 5, 33944)
# (array([2, 2, 2, 2], dtype=int32), 6, 33945)
# (array([1, 1, 1, 1], dtype=int32), 4, 33946)
# (array([2, 2, 2, 2], dtype=int32), 5, 33947)
# (array([1, 2, 1, 2], dtype=int32), 5, 33948)
# (array([1, 1, 1, 1], dtype=int32), 4, 33949)
# (array([2, 2, 2, 2], dtype=int32), 5, 33950)
# (array([1, 2, 1, 2], dtype=int32), 5, 33951)
# (array([2, 1, 2, 1], dtype=int32), 6, 33952)
# (array([1, 1, 1, 1], dtype=int32), 5, 33953)
# (array([2, 2, 2, 2], dtype=int32), 6, 33954)
# (array([1, 1, 1, 1], dtype=int32), 4, 33955)
# (array([2, 2, 2, 2], dtype=int32), 5, 33956)
# (array([1, 2, 1, 2], dtype=int32), 5, 33957)
# (array([2, 1, 2, 1], dtype=int32), 6, 33958)
# (array([1, 1, 1, 1], dtype=int32), 5, 33959)
# (array([2, 2, 2, 2], dtype=int32), 6, 33960)
# (array([1, 1, 1, 1], dtype=int32), 4, 33961)
# (array([2, 2, 2, 2], dtype=int32), 5, 33962)
# (array([1, 2, 1, 2], dtype=int32), 5, 33963)
# (array([2, 1, 2, 1], dtype=int32), 6, 33964)
# (array([1, 1, 1, 1], dtype=int32), 5, 33965)
# (array([2, 2, 2, 2], dtype=int32), 6, 33966)
# (array([1, 1, 1, 1], dtype=int32), 4, 33967)
# (array([2, 2, 2, 2], dtype=int32), 5, 33968)
# (array([1, 2, 1, 2], dtype=int32), 5, 33969)
# (array([2, 1, 2, 1], dtype=int32), 6, 33970)
# (array([1, 1, 1, 1], dtype=int32), 5, 33971)
# (array([2, 2, 2, 2], dtype=int32), 6, 33972)
# (array([1, 1, 1, 1], dtype=int32), 4, 33973)
# (array([2, 2, 2, 2], dtype=int32), 5, 33974)
# (array([1, 2, 1, 2], dtype=int32), 5, 33975)
# (array([2, 1, 2, 1], dtype=int32), 6, 33976)
# (array([1, 1, 1, 1], dtype=int32), 5, 33977)
# (array([2, 2, 2, 2], dtype=int32), 6, 33978)
# (array([2, 1, 2, 1], dtype=int32), 6, 33979)
# (array([1, 1, 1, 1], dtype=int32), 5, 33980)
# (array([2, 2, 2, 2], dtype=int32), 6, 33981)
# (array([1, 1, 1, 1], dtype=int32), 4, 33982)
# (array([2, 2, 2, 2], dtype=int32), 5, 33983)
# (array([1, 2, 1, 2], dtype=int32), 5, 33984)
# (array([1, 1, 1, 1], dtype=int32), 4, 33985)
# (array([2, 2, 2, 2], dtype=int32), 5, 33986)
# (array([1, 2, 1, 2], dtype=int32), 5, 33987)
# (array([2, 1, 2, 1], dtype=int32), 6, 33988)
# (array([1, 1, 1, 1], dtype=int32), 5, 33989)
# (array([2, 2, 2, 2], dtype=int32), 6, 33990)
# (array([1, 1, 1, 1], dtype=int32), 4, 33991)
# (array([2, 2, 2, 2], dtype=int32), 5, 33992)
# (array([1, 2, 1, 2], dtype=int32), 5, 33993)
# (array([2, 1, 2, 1], dtype=int32), 6, 33994)
# (array([1, 1, 1, 1], dtype=int32), 5, 33995)
# (array([2, 2, 2, 2], dtype=int32), 6, 33996)
# (array([2, 1, 2, 1], dtype=int32), 6, 33997)
# (array([1, 1, 1, 1], dtype=int32), 5, 33998)
# (array([2, 2, 2, 2], dtype=int32), 6, 33999)
# (array([1, 1, 1, 1], dtype=int32), 4, 34000)
# (array([2, 2, 2, 2], dtype=int32), 5, 34001)
# (array([1, 2, 1, 2], dtype=int32), 5, 34002)
# (array([1, 1, 1, 1], dtype=int32), 4, 34003)
# (array([2, 2, 2, 2], dtype=int32), 5, 34004)
# (array([1, 2, 1, 2], dtype=int32), 5, 34005)
# (array([2, 1, 2, 1], dtype=int32), 6, 34006)
# (array([1, 1, 1, 1], dtype=int32), 5, 34007)
# (array([2, 2, 2, 2], dtype=int32), 6, 34008)
# (array([2, 1, 2, 1], dtype=int32), 6, 34009)
# (array([1, 1, 1, 1], dtype=int32), 5, 34010)
# (array([2, 2, 2, 2], dtype=int32), 6, 34011)
# (array([1, 1, 1, 1], dtype=int32), 4, 34012)
# (array([2, 2, 2, 2], dtype=int32), 5, 34013)
# (array([1, 2, 1, 2], dtype=int32), 5, 34014)
# (array([1, 1, 1, 1], dtype=int32), 4, 34015)
# (array([2, 2, 2, 2], dtype=int32), 5, 34016)
# (array([1, 2, 1, 2], dtype=int32), 5, 34017)
# (array([2, 1, 2, 1], dtype=int32), 6, 34018)
# (array([1, 1, 1, 1], dtype=int32), 5, 34019)
# (array([2, 2, 2, 2], dtype=int32), 6, 34020)
# (array([1, 1, 1, 1], dtype=int32), 4, 34021)
# (array([2, 2, 2, 2], dtype=int32), 5, 34022)
# (array([1, 2, 1, 2], dtype=int32), 5, 34023)
# (array([2, 1, 2, 1], dtype=int32), 6, 34024)
# (array([1, 1, 1, 1], dtype=int32), 5, 34025)
# (array([2, 2, 2, 2], dtype=int32), 6, 34026)
# (array([2, 1, 2, 1], dtype=int32), 6, 34027)
# (array([1, 1, 1, 1], dtype=int32), 5, 34028)
# (array([2, 2, 2, 2], dtype=int32), 6, 34029)
# (array([1, 1, 1, 1], dtype=int32), 4, 34030)
# (array([2, 2, 2, 2], dtype=int32), 5, 34031)
# (array([1, 2, 1, 2], dtype=int32), 5, 34032)
# (array([2, 1, 2, 1], dtype=int32), 6, 34033)
# (array([1, 1, 1, 1], dtype=int32), 5, 34034)
# (array([2, 2, 2, 2], dtype=int32), 6, 34035)
# (array([1, 1, 1, 1], dtype=int32), 4, 34036)
# (array([2, 2, 2, 2], dtype=int32), 5, 34037)
# (array([1, 2, 1, 2], dtype=int32), 5, 34038)
# (array([1, 1, 1, 1], dtype=int32), 4, 34039)
# (array([2, 2, 2, 2], dtype=int32), 5, 34040)
# (array([1, 2, 1, 2], dtype=int32), 5, 34041)
# (array([2, 1, 2, 1], dtype=int32), 6, 34042)
# (array([1, 1, 1, 1], dtype=int32), 5, 34043)
# (array([2, 2, 2, 2], dtype=int32), 6, 34044)
# (array([2, 1, 2, 1], dtype=int32), 6, 34045)
# (array([1, 1, 1, 1], dtype=int32), 5, 34046)
# (array([2, 2, 2, 2], dtype=int32), 6, 34047)
# (array([1, 1, 1, 1], dtype=int32), 4, 34048)
# (array([2, 2, 2, 2], dtype=int32), 5, 34049)
# (array([1, 2, 1, 2], dtype=int32), 5, 34050)
# (array([2, 1, 2, 1], dtype=int32), 6, 34051)
# (array([1, 1, 1, 1], dtype=int32), 5, 34052)
# (array([2, 2, 2, 2], dtype=int32), 6, 34053)
# (array([1, 1, 1, 1], dtype=int32), 4, 34054)
# (array([2, 2, 2, 2], dtype=int32), 5, 34055)
# (array([1, 2, 1, 2], dtype=int32), 5, 34056)
# (array([1, 1, 1, 1], dtype=int32), 4, 34057)
# (array([2, 2, 2, 2], dtype=int32), 5, 34058)
# (array([1, 2, 1, 2], dtype=int32), 5, 34059)
# (array([2, 1, 2, 1], dtype=int32), 6, 34060)
# (array([1, 1, 1, 1], dtype=int32), 5, 34061)
# (array([2, 2, 2, 2], dtype=int32), 6, 34062)
# (array([1, 1, 1, 1], dtype=int32), 4, 34063)
# (array([2, 2, 2, 2], dtype=int32), 5, 34064)
# (array([1, 2, 1, 2], dtype=int32), 5, 34065)
# (array([2, 1, 2, 1], dtype=int32), 6, 34066)
# (array([1, 1, 1, 1], dtype=int32), 5, 34067)
# (array([2, 2, 2, 2], dtype=int32), 6, 34068)
# (array([2, 1, 2, 1], dtype=int32), 6, 34069)
# (array([1, 1, 1, 1], dtype=int32), 5, 34070)
# (array([2, 2, 2, 2], dtype=int32), 6, 34071)
# (array([1, 1, 1, 1], dtype=int32), 4, 34072)
# (array([2, 2, 2, 2], dtype=int32), 5, 34073)
# (array([1, 2, 1, 2], dtype=int32), 5, 34074)
# (array([1, 1, 1, 1], dtype=int32), 4, 34075)
# (array([2, 2, 2, 2], dtype=int32), 5, 34076)
# (array([1, 2, 1, 2], dtype=int32), 5, 34077)
# (array([2, 1, 2, 1], dtype=int32), 6, 34078)
# (array([1, 1, 1, 1], dtype=int32), 5, 34079)
# (array([2, 2, 2, 2], dtype=int32), 6, 34080)
# (array([1, 1, 1, 1], dtype=int32), 4, 34081)
# (array([2, 2, 2, 2], dtype=int32), 5, 34082)
# (array([1, 2, 1, 2], dtype=int32), 5, 34083)
# (array([2, 1, 2, 1], dtype=int32), 6, 34084)
# (array([1, 1, 1, 1], dtype=int32), 5, 34085)
# (array([2, 2, 2, 2], dtype=int32), 6, 34086)
# (array([1, 1, 1, 1], dtype=int32), 4, 34087)
# (array([2, 2, 2, 2], dtype=int32), 5, 34088)
# (array([1, 2, 1, 2], dtype=int32), 5, 34089)
# (array([2, 1, 2, 1], dtype=int32), 6, 34090)
# (array([1, 1, 1, 1], dtype=int32), 5, 34091)
# (array([2, 2, 2, 2], dtype=int32), 6, 34092)
# (array([1, 1, 1, 1], dtype=int32), 4, 34093)
# (array([2, 2, 2, 2], dtype=int32), 5, 34094)
# (array([1, 2, 1, 2], dtype=int32), 5, 34095)
# (array([2, 1, 2, 1], dtype=int32), 6, 34096)
# (array([1, 1, 1, 1], dtype=int32), 5, 34097)
# (array([2, 2, 2, 2], dtype=int32), 6, 34098)
# (array([1, 1, 1, 1], dtype=int32), 4, 34099)
# (array([2, 2, 2, 2], dtype=int32), 5, 34100)
# (array([1, 2, 1, 2], dtype=int32), 5, 34101)
# (array([2, 1, 2, 1], dtype=int32), 6, 34102)
# (array([1, 1, 1, 1], dtype=int32), 5, 34103)
# (array([2, 2, 2, 2], dtype=int32), 6, 34104)
# (array([1, 1, 1, 1], dtype=int32), 4, 34105)
# (array([2, 2, 2, 2], dtype=int32), 5, 34106)
# (array([1, 2, 1, 2], dtype=int32), 5, 34107)
# (array([2, 1, 2, 1], dtype=int32), 6, 34108)
# (array([1, 1, 1, 1], dtype=int32), 5, 34109)
# (array([2, 2, 2, 2], dtype=int32), 6, 34110)
# (array([2, 1, 2, 1], dtype=int32), 6, 34111)
# (array([1, 1, 1, 1], dtype=int32), 5, 34112)
# (array([2, 2, 2, 2], dtype=int32), 6, 34113)
# (array([1, 1, 1, 1], dtype=int32), 4, 34114)
# (array([2, 2, 2, 2], dtype=int32), 5, 34115)
# (array([1, 2, 1, 2], dtype=int32), 5, 34116)
# (array([2, 1, 2, 1], dtype=int32), 6, 34117)
# (array([1, 1, 1, 1], dtype=int32), 5, 34118)
# (array([2, 2, 2, 2], dtype=int32), 6, 34119)
# (array([1, 1, 1, 1], dtype=int32), 4, 34120)
# (array([2, 2, 2, 2], dtype=int32), 5, 34121)
# (array([1, 2, 1, 2], dtype=int32), 5, 34122)
# (array([2, 1, 2, 1], dtype=int32), 6, 34123)
# (array([1, 1, 1, 1], dtype=int32), 5, 34124)
# (array([2, 2, 2, 2], dtype=int32), 6, 34125)
# (array([1, 1, 1, 1], dtype=int32), 4, 34126)
# (array([2, 2, 2, 2], dtype=int32), 5, 34127)
# (array([1, 2, 1, 2], dtype=int32), 5, 34128)
# (array([1, 1, 1, 1], dtype=int32), 4, 34129)
# (array([2, 2, 2, 2], dtype=int32), 5, 34130)
# (array([1, 2, 1, 2], dtype=int32), 5, 34131)
# (array([2, 1, 2, 1], dtype=int32), 6, 34132)
# (array([1, 1, 1, 1], dtype=int32), 5, 34133)
# (array([2, 2, 2, 2], dtype=int32), 6, 34134)
# (array([2, 1, 2, 1], dtype=int32), 6, 34135)
# (array([1, 1, 1, 1], dtype=int32), 5, 34136)
# (array([2, 2, 2, 2], dtype=int32), 6, 34137)
# (array([1, 1, 1, 1], dtype=int32), 4, 34138)
# (array([2, 2, 2, 2], dtype=int32), 5, 34139)
# (array([1, 2, 1, 2], dtype=int32), 5, 34140)
# (array([2, 1, 2, 1], dtype=int32), 6, 34141)
# (array([1, 1, 1, 1], dtype=int32), 5, 34142)
# (array([2, 2, 2, 2], dtype=int32), 6, 34143)
# (array([1, 1, 1, 1], dtype=int32), 4, 34144)
# (array([2, 2, 2, 2], dtype=int32), 5, 34145)
# (array([1, 2, 1, 2], dtype=int32), 5, 34146)
# (array([2, 1, 2, 1], dtype=int32), 6, 34147)
# (array([1, 1, 1, 1], dtype=int32), 5, 34148)
# (array([2, 2, 2, 2], dtype=int32), 6, 34149)
# (array([1, 1, 1, 1], dtype=int32), 4, 34150)
# (array([2, 2, 2, 2], dtype=int32), 5, 34151)
# (array([1, 2, 1, 2], dtype=int32), 5, 34152)
# (array([1, 1, 1, 1], dtype=int32), 4, 34153)
# (array([2, 2, 2, 2], dtype=int32), 5, 34154)
# (array([1, 2, 1, 2], dtype=int32), 5, 34155)
# (array([2, 1, 2, 1], dtype=int32), 6, 34156)
# (array([1, 1, 1, 1], dtype=int32), 5, 34157)
# (array([2, 2, 2, 2], dtype=int32), 6, 34158)
# (array([2, 1, 2, 1], dtype=int32), 6, 34159)
# (array([1, 1, 1, 1], dtype=int32), 5, 34160)
# (array([2, 2, 2, 2], dtype=int32), 6, 34161)
# (array([1, 1, 1, 1], dtype=int32), 4, 34162)
# (array([2, 2, 2, 2], dtype=int32), 5, 34163)
# (array([1, 2, 1, 2], dtype=int32), 5, 34164)
# (array([2, 1, 2, 1], dtype=int32), 6, 34165)
# (array([1, 1, 1, 1], dtype=int32), 5, 34166)
# (array([2, 2, 2, 2], dtype=int32), 6, 34167)
# (array([1, 1, 1, 1], dtype=int32), 4, 34168)
# (array([2, 2, 2, 2], dtype=int32), 5, 34169)
# (array([1, 2, 1, 2], dtype=int32), 5, 34170)
# (array([1, 1, 1, 1], dtype=int32), 4, 34171)
# (array([2, 2, 2, 2], dtype=int32), 5, 34172)
# (array([1, 2, 1, 2], dtype=int32), 5, 34173)
# (array([2, 1, 2, 1], dtype=int32), 6, 34174)
# (array([1, 1, 1, 1], dtype=int32), 5, 34175)
# (array([2, 2, 2, 2], dtype=int32), 6, 34176)
# (array([2, 1, 2, 1], dtype=int32), 6, 34177)
# (array([1, 1, 1, 1], dtype=int32), 5, 34178)
# (array([2, 2, 2, 2], dtype=int32), 6, 34179)
# (array([1, 1, 1, 1], dtype=int32), 4, 34180)
# (array([2, 2, 2, 2], dtype=int32), 5, 34181)
# (array([1, 2, 1, 2], dtype=int32), 5, 34182)
# (array([2, 1, 2, 1], dtype=int32), 6, 34183)
# (array([1, 1, 1, 1], dtype=int32), 5, 34184)
# (array([2, 2, 2, 2], dtype=int32), 6, 34185)
# (array([1, 1, 1, 1], dtype=int32), 4, 34186)
# (array([2, 2, 2, 2], dtype=int32), 5, 34187)
# (array([1, 2, 1, 2], dtype=int32), 5, 34188)
# (array([1, 1, 1, 1], dtype=int32), 4, 34189)
# (array([2, 2, 2, 2], dtype=int32), 5, 34190)
# (array([1, 2, 1, 2], dtype=int32), 5, 34191)
# (array([2, 1, 2, 1], dtype=int32), 6, 34192)
# (array([1, 1, 1, 1], dtype=int32), 5, 34193)
# (array([2, 2, 2, 2], dtype=int32), 6, 34194)
# (array([1, 1, 1, 1], dtype=int32), 4, 34195)
# (array([2, 2, 2, 2], dtype=int32), 5, 34196)
# (array([1, 2, 1, 2], dtype=int32), 5, 34197)
# (array([2, 1, 2, 1], dtype=int32), 6, 34198)
# (array([1, 1, 1, 1], dtype=int32), 5, 34199)
# (array([2, 2, 2, 2], dtype=int32), 6, 34200)
# (array([1, 1, 1, 1], dtype=int32), 4, 34201)
# (array([2, 2, 2, 2], dtype=int32), 5, 34202)
# (array([1, 2, 1, 2], dtype=int32), 5, 34203)
# (array([2, 1, 2, 1], dtype=int32), 6, 34204)
# (array([1, 1, 1, 1], dtype=int32), 5, 34205)
# (array([2, 2, 2, 2], dtype=int32), 6, 34206)
# (array([2, 1, 2, 1], dtype=int32), 6, 34207)
# (array([1, 1, 1, 1], dtype=int32), 5, 34208)
